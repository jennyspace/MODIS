# %%
### 14/09/2016 - Add Cloud phase info to a df and a file --------------------------------------------
### 29/08/2016 - Read reff from MODIS data to df and save in a file ---------------------------------

# %%
from numpy import *
from pyhdf.SD import SD
from scipy import array
import numpy as np
import pandas as pd

### file location should be correct otherwise will get SD error msg
'''
filename = "./20130614/Reff/MYD06_L2.A2013165.0420.006.2014266205611.hdf"  
filename2 = "./20130614/Reff/MYD03.A2013165.0420.006.2013165155508.hdf"
FDate="20130614_133658"

filename = "./20130628/Reff/MYD06_L2.A2013179.0430.006.2014267001301.hdf"  
filename2 = "./20130628/Reff/MYD03.A2013179.0430.006.2013179161739.hdf"
FDate="20130628_130139"

filename = "./20130707/Reff/MYD06_L2.A2013188.0425.006.2014267025147.hdf"  
filename2 = "./20130707/Reff/MYD03.A2013188.0425.006.2013188151355.hdf"
FDate="20130707_125944"

filename = "./20150830/Reff/MYD06_L2.A2015242.0425.006.2015243234239.hdf"  
filename2 = "./20150830/Reff/MYD03.A2015242.0425.006.2015243130645.hdf"
FDate="20150830_130524"

filename = "./20130723/Reff/MYD06_L2.A2013204.0425.006.2014267101648.hdf"  
filename2 = "./20130723/Reff/MYD03.A2013204.0425.006.2013205024031.hdf"
FDate="20130723_130219"

filename = "./20130806/Reff/MYD06_L2.A2013218.0440.006.2014267174320.hdf" ### AC flew after overpass
filename2 = "./20130806/Reff/MYD03.A2013218.0440.006.2013218171157.hdf"
FDate="20130806_151347"

filename = "./20130815/Reff/MYD06_L2.A2013227.0430.006.2014267173440.hdf"  
filename2 = "./20130815/Reff/MYD03.A2013227.0430.006.2013227204402.hdf"
FDate="20130815_122404"

filename = "./20130907/Reff/MYD06_L2.A2013250.0435.006.2014267090313.hdf"  
filename2 = "./20130907/Reff/MYD03.A2013250.0435.006.2013250172454.hdf"
FDate="20130907_122442"

filename = "./20131011/Reff/MYD06_L2.A2013284.0425.006.2014268093706.hdf"  
filename2 = "./20131011/Reff/MYD03.A2013284.0425.006.2013298033119.hdf"
FDate="20131011_132432"

filename = "./20140806/Reff/MYD06_L2.A2014218.0405.006.2014271211204.hdf"  
filename2 = "./20140806/Reff/MYD03.A2014218.0405.006.2014220175309.hdf"
FDate="20140806_150804"

filename = "./20140903/Reff/MYD06_L2.A2014246.0430.006.2014272144020.hdf"  
filename2 = "./20140903/Reff/MYD03.A2014246.0430.006.2014246153856.hdf"
FDate="20140903_124321"

filename = "./20140912/Reff/MYD06_L2.A2014255.0425.006.2014282201310.hdf"  
filename2 = "./20140912/Reff/MYD03.A2014255.0425.006.2014261140010.hdf"
FDate="20140912_124317"
'''
filename = "./20151001/Reff/MYD06_L2.A2015274.0425.006.2015274203619.hdf"  
filename2 = "./20151001/Reff/MYD03.A2015274.0425.006.2015274154732.hdf"
FDate="20151001_123025"

### read a file
f=SD(filename)
f2=SD(filename2)

# %%
df = pd.DataFrame({'FDate': FDate,'lat': lst_lat, 'lon': lst_lon,'SZA': lst_SZA, \
                    'CTT': lst_CTT, 'CTH': lst_CTH, 'CTP': lst_CTP, 'CPI': lst_CPI, \
                   'CPOP', lst_CPOP, 'reff_16': lst_reff_16, 'reff_16_PCL': lst_reff_16_PCL, \
                   'reff_21': lst_reff_21, 'reff_21_PCL': lst_reff_21_PCL, \
                   'reff_37': lst_reff_37, 'reff_37_PCL': lst_reff_37_PCL,\
                   'COT_16': lst_COT_16, 'COT_16_PCL': lst_COT_16_PCL, \
                   'COT_21': lst_COT_21, 'COT_21_PCL': lst_COT_21_PCL, \
                   'COT_37': lst_COT_37, 'COT_37_PCL': lst_COT_37_PCL, \
                   'CWP': lst_CWP, 'CMLF': lst_CMLF},\
                  index=range(len(lst_lat)))

# %%
CPOP[0]
# Out:
# array([0, 3, 3, ..., 2, 2, 0], dtype=int8)

# %%
### 1) Read parameters & lat/long and 
### 2) save them to a dataframe
### 3) then save to a file for each flight

lat = array(f2.select('Latitude').get())
lon = array(f2.select('Longitude').get())
SZA = array(f2.select('SolarZenith').get())

CTT = array(f.select('cloud_top_temperature_1km').get()) * 0.009999
CTH = array(f.select('cloud_top_height_1km').get()) 
CTP = array(f.select('cloud_top_pressure_1km').get()) * 0.1
CPI = array(f.select('Cloud_Phase_Infrared_1km').get())

CPOP = array(f.select('Cloud_Phase_Optical_Properties').get())
reff_16 = array(f.select('Cloud_Effective_Radius_16').get()) * 0.009999 ### this works, 20130723
reff_16_PCL = array(f.select('Cloud_Effective_Radius_16_PCL').get())* 0.009999
reff_21 = array(f.select('Cloud_Effective_Radius').get())* 0.009999
reff_21_PCL = array(f.select('Cloud_Effective_Radius_PCL').get())* 0.009999
reff_37 = array(f.select('Cloud_Effective_Radius_37').get())* 0.009999
reff_37_PCL = array(f.select('Cloud_Effective_Radius_37_PCL').get())* 0.009999

COT_16 = array(f.select('Cloud_Optical_Thickness_16').get())* 0.009999
COT_16_PCL = array(f.select('Cloud_Optical_Thickness_16_PCL').get())* 0.009999
COT_21 = array(f.select('Cloud_Optical_Thickness').get())* 0.009999
COT_21_PCL = array(f.select('Cloud_Optical_Thickness_PCL').get())* 0.009999
COT_37 = array(f.select('Cloud_Optical_Thickness_37').get())* 0.009999
COT_37_PCL = array(f.select('Cloud_Optical_Thickness_37_PCL').get())* 0.009999

CWP = array(f.select('Cloud_Water_Path').get())
CMLF = array(f.select('Cloud_Multi_Layer_Flag').get())

### Create 3 colums of lat1, long1, and reff having 1354 X 2030 rows ----------------------------
### Because the elements of lat1 is an array (1 X 1354), to be data for dataframe, it should be converted to a list

lst_lat = list(lat[0])
lst_lon = list(lon[0])
lst_SZA = list(SZA[0])

lst_CTT = list(CTT[0])
lst_CTH = list(CTH[0])
lst_CTP = list(CTP[0])
lst_CPI = list(CPI[0])

lst_CPOP = list(CPOP[0])
lst_reff_16 = list(reff_16[0])
lst_reff_16_PCL = list(reff_16_PCL[0])
lst_reff_21 = list(reff_21[0])
lst_reff_21_PCL = list(reff_21_PCL[0])
lst_reff_37 = list(reff_37[0])
lst_reff_37_PCL = list(reff_37_PCL[0])

lst_COT_16 = list(COT_16[0])
lst_COT_16_PCL = list(COT_16_PCL[0])
lst_COT_21 = list(COT_21[0])
lst_COT_21_PCL = list(COT_21_PCL[0])
lst_COT_37 = list(COT_37[0])
lst_COT_37_PCL = list(COT_37_PCL[0])

lst_CWP = list(CWP[0])
lst_CMLF = list(CMLF[0])

df = pd.DataFrame({'FDate': FDate,'lat': lst_lat, 'lon': lst_lon,'SZA': lst_SZA, \
                   'CTT': lst_CTT, 'CTH': lst_CTH, 'CTP': lst_CTP, 'CPI': lst_CPI, \
                   'CPOP': lst_CPOP, 'reff_16': lst_reff_16, 'reff_16_PCL': lst_reff_16_PCL, \
                   'reff_21': lst_reff_21, 'reff_21_PCL': lst_reff_21_PCL, \
                   'reff_37': lst_reff_37, 'reff_37_PCL': lst_reff_37_PCL,\
                   'COT_16': lst_COT_16, 'COT_16_PCL': lst_COT_16_PCL, \
                   'COT_21': lst_COT_21, 'COT_21_PCL': lst_COT_21_PCL, \
                   'COT_37': lst_COT_37, 'COT_37_PCL': lst_COT_37_PCL, \
                   'CWP': lst_CWP, 'CMLF': lst_CMLF},\
                  index=range(len(lst_lat))) 

lst_lat2 = list(lat[1])
lst_lon2 = list(lon[1])
lst_SZA2 = list(SZA[1])

lst_CTT2 = list(CTT[1])
lst_CTH2 = list(CTH[1])
lst_CTP2 = list(CTP[1])
lst_CPI2 = list(CPI[1])

lst_CPOP2 = list(CPOP[1])
lst_reff_16_2 = list(reff_16[1])
lst_reff_16_PCL_2 = list(reff_16_PCL[1])
lst_reff_21_2 = list(reff_21[1])
lst_reff_21_PCL_2 = list(reff_21_PCL[1])
lst_reff_37_2 = list(reff_37[1])
lst_reff_37_PCL_2 = list(reff_37_PCL[1])

lst_COT_16_2 = list(COT_16[1])
lst_COT_16_PCL_2 = list(COT_16_PCL[1])
lst_COT_21_2 = list(COT_21[1])
lst_COT_21_PCL_2 = list(COT_21_PCL[1])
lst_COT_37_2 = list(COT_37[1])
lst_COT_37_PCL_2 = list(COT_37_PCL[1])

lst_CWP2 = list(CWP[1])
lst_CMLF2 = list(CMLF[1])

df2 = pd.DataFrame({'FDate': FDate,'lat': lst_lat2, 'lon': lst_lon2, 'SZA': lst_SZA2,\
                   'CTT': lst_CTT2, 'CTH': lst_CTH2, 'CTP': lst_CTP2, 'CPI': lst_CPI2,\
                   'CPOP': lst_CPOP2, 'reff_16': lst_reff_16_2, 'reff_16_PCL': lst_reff_16_PCL_2,\
                   'reff_21': lst_reff_21_2, 'reff_21_PCL': lst_reff_21_PCL_2,\
                   'reff_37': lst_reff_37_2, 'reff_37_PCL': lst_reff_37_PCL_2,\
                   'COT_16': lst_COT_16_2, 'COT_16_PCL': lst_COT_16_PCL_2, \
                   'COT_21': lst_COT_21_2, 'COT_21_PCL': lst_COT_21_PCL_2, \
                   'COT_37': lst_COT_37_2, 'COT_37_PCL': lst_COT_37_PCL_2, \
                   'CWP': lst_CWP2, 'CMLF': lst_CMLF2}, \
                   index=range(len(lst_lat))) 

frames = [ df, df2]
frames = pd.concat(frames)

for j in range(2030-2):
    
    lst_lat = list(lat[j+2])
    lst_lon = list(lon[j+2])
    lst_SZA = list(SZA[j+2])

    lst_CTT = list(CTT[j+2])
    lst_CTH = list(CTH[j+2])
    lst_CTP = list(CTP[j+2])
    lst_CPI = list(CPI[j+2])

    lst_CPOP = list(CPOP[j+2])
    lst_reff_16 = list(reff_16[j+2])
    lst_reff_16_PCL = list(reff_16_PCL[j+2])
    lst_reff_21 = list(reff_21[j+2])
    lst_reff_21_PCL = list(reff_21_PCL[j+2])
    lst_reff_37 = list(reff_37[j+2])
    lst_reff_37_PCL = list(reff_37_PCL[j+2])

    lst_COT_16 = list(COT_16[j+2])
    lst_COT_16_PCL = list(COT_16_PCL[j+2])
    lst_COT_21 = list(COT_21[j+2])
    lst_COT_21_PCL = list(COT_21_PCL[j+2])
    lst_COT_37 = list(COT_37[j+2])
    lst_COT_37_PCL = list(COT_37_PCL[j+2])

    lst_CWP = list(CWP[j+2])
    lst_CMLF = list(CMLF[j+2])
    df= pd.DataFrame({'FDate': FDate,'lat': lst_lat, 'lon': lst_lon,'SZA': lst_SZA, \
                       'CTT': lst_CTT, 'CTH': lst_CTH, 'CTP': lst_CTP, 'CPI': lst_CPI, \
                       'CPOP': lst_CPOP, 'reff_16': lst_reff_16, 'reff_16_PCL': lst_reff_16_PCL, \
                       'reff_21': lst_reff_21, 'reff_21_PCL': lst_reff_21_PCL, \
                       'reff_37': lst_reff_37, 'reff_37_PCL': lst_reff_37_PCL,\
                       'COT_16': lst_COT_16, 'COT_16_PCL': lst_COT_16_PCL, \
                       'COT_21': lst_COT_21, 'COT_21_PCL': lst_COT_21_PCL, \
                       'COT_37': lst_COT_37, 'COT_37_PCL': lst_COT_37_PCL, \
                       'CWP': lst_CWP, 'CMLF': lst_CMLF},\
                      index=range(len(lst_lat))) 
    frames = [ frames, df]
    frames = pd.concat(frames)
    
### Save the frames to a file
frames.to_csv('MODIS_' + FDate + '.csv', mode='w')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-48e22e4a21ea> in <module>()
#     124     df= pd.DataFrame({'FDate': FDate,'lat': lst_lat, 'lon': lst_lon,'SZA': lst_SZA,                        'CTT': lst_CTT, 'CTH': lst_CTH, 'CTP': lst_CTP, 'CPI': lst_CPI,                        'CPOP': lst_CPOP, 'reff_16': lst_reff_16, 'reff_16_PCL': lst_reff_16_PCL,                        'reff_21': lst_reff_21, 'reff_21_PCL': lst_reff_21_PCL,                        'reff_37': lst_reff_37, 'reff_37_PCL': lst_reff_37_PCL,                       'COT_16': lst_COT_16, 'COT_16_PCL': lst_COT_16_PCL,                        'COT_21': lst_COT_21, 'COT_21_PCL': lst_COT_21_PCL,                        'COT_37': lst_COT_37, 'COT_37_PCL': lst_COT_37_PCL,                        'CWP': lst_CWP, 'CMLF': lst_CMLF},                      index=range(len(lst_lat)))
#     125     frames = [ frames, df]
# --> 126     frames = pd.concat(frames)
#     127
#     128 ### Save the frames to a file and read
#
# /home/eunmia/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/tools/merge.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity)
#     715                        ignore_index=ignore_index, join=join,
#     716                        keys=keys, levels=levels, names=names,
# --> 717                        verify_integrity=verify_integrity)
#     718     return op.get_result()
#     719
#
# /home/eunmia/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/tools/merge.pyc in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity)
#     769
#     770             # consolidate
# --> 771             obj.consolidate(inplace=True)
#     772             ndims.add(obj.ndim)
#     773
#
# /home/eunmia/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/generic.pyc in consolidate(self, inplace)
#    1888         """
#    1889         if inplace:
# -> 1890             self._consolidate_inplace()
#    1891         else:
#    1892             f = lambda: self._data.consolidate()
#
# /home/eunmia/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/generic.pyc in _consolidate_inplace(self)
#    1870     def _consolidate_inplace(self):
#    1871         f = lambda: self._data.consolidate()
# -> 1872         self._data = self._protect_consolidate(f)
#    1873
#    1874     def consolidate(self, inplace=False):
#
# /home/eunmia/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/generic.pyc in _protect_consolidate(self, f)
#    1913     def _protect_consolidate(self, f):
#    1914         blocks_before = len(self._data.blocks)
# -> 1915         result = f()
#    1916         if len(self._data.blocks) != blocks_before:
#    1917             self._clear_item_cache()
#
# /home/eunmia/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/generic.pyc in <lambda>()
#    1869
#    1870     def _consolidate_inplace(self):
# -> 1871         f = lambda: self._data.consolidate()
#    1872         self._data = self._protect_consolidate(f)
#    1873
#
# /home/eunmia/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/internals.pyc in consolidate(self)
#    2517
#    2518         bm = self.__class__(self.blocks, self.axes)
# -> 2519         bm._consolidate_inplace()
#    2520         return bm
#    2521
#
# /home/eunmia/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/internals.pyc in _consolidate_inplace(self)
#    2522     def _consolidate_inplace(self):
#    2523         if not self.is_consolidated():
# -> 2524             self.blocks = tuple(_consolidate(self.blocks))
#    2525
#    2526             self._is_consolidated = True
#
# /home/eunmia/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/internals.pyc in _consolidate(blocks)
#    3441     for (_can_consolidate, dtype), group_blocks in grouper:
#    3442         merged_blocks = _merge_blocks(list(group_blocks), dtype=dtype,
# -> 3443                                       _can_consolidate=_can_consolidate)
#    3444         if isinstance(merged_blocks, list):
#    3445             new_blocks.extend(merged_blocks)
#
# /home/eunmia/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/internals.pyc in _merge_blocks(blocks, dtype, _can_consolidate)
#    3464         # combination of those slices is a slice, too.
#    3465         new_mgr_locs = np.concatenate([b.mgr_locs.as_array for b in blocks])
# -> 3466         new_values = _vstack([b.values for b in blocks], dtype)
#    3467
#    3468         argsort = np.argsort(new_mgr_locs)
#
# /home/eunmia/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/internals.pyc in _vstack(to_stack, dtype)
#    3494
#    3495     else:
# -> 3496         return np.vstack(to_stack)
#    3497
#    3498
#
# /home/eunmia/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/numpy/core/shape_base.pyc in vstack(tup)
#     226
#     227     """
# --> 228     return _nx.concatenate([atleast_2d(_m) for _m in tup], 0)
#     229
#     230 def hstack(tup):
#
# KeyboardInterrupt:
