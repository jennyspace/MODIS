# %%
### 14/09/2016 - Add Cloud phase info to a df and a file --------------------------------------------
### 29/08/2016 - Read reff from MODIS data to df and save in a file ---------------------------------
### To save the calculation time and file size, I limited the MODIS data by manually checking the lat-long
### data (MY03) with HDF viewer except 0723 and 20130806 cases ------------------------------------------

# %%
from numpy import *
from pyhdf.SD import SD
from scipy import array
import numpy as np
import pandas as pd

### file location should be correct otherwise will get SD error msg
'''
filename = "./20130614/Reff/MYD06_L2.A2013165.0420.006.2014266205611.hdf"  
filename2 = "./20130614/Reff/MYD03.A2013165.0420.006.2013165155508.hdf"
FDate="20130614_133658"
lat_min_index = 256 ## -45S (322)
lat_max_index = 984 ## -42 (922)

filename = "./20130628/Reff/MYD06_L2.A2013179.0430.006.2014267001301.hdf"  
filename2 = "./20130628/Reff/MYD03.A2013179.0430.006.2013179161739.hdf"
FDate="20130628_130139"
lat_min_index = 1130 ## -45S  (-44.52: 1185)
lat_max_index = 1863 ## -43   (-43.33 1824)

filename = "./20130707/Reff/MYD06_L2.A2013188.0425.006.2014267025147.hdf"  
filename2 = "./20130707/Reff/MYD03.A2013188.0425.006.2013188151355.hdf"
FDate="20130707_125944"
lat_min_index = 631 ## -45.26
lat_max_index = 1285 ## -43.97

filename = "./20130723/Reff/MYD06_L2.A2013204.0425.006.2014267101648.hdf"  
filename2 = "./20130723/Reff/MYD03.A2013204.0425.006.2013205024031.hdf"
FDate="20130723_130219"
'''
filename = "./20130806/Reff/MYD06_L2.A2013218.0440.006.2014267174320.hdf" ### AC flew after overpass
filename2 = "./20130806/Reff/MYD03.A2013218.0440.006.2013218171157.hdf"
#filename = "./20130806/Reff/MYD06_L2.A2013218.0435.006.2014267182241.hdf"
#filename2 = "./20130806/Reff/MYD03.A2013218.0435.006.2013218172548.hdf"
FDate="20130806_151347"
lat_min_index = 0 ## 
lat_max_index = 620 ## 

'''
filename = "./20130815/Reff/MYD06_L2.A2013227.0430.006.2014267173440.hdf"  
filename2 = "./20130815/Reff/MYD03.A2013227.0430.006.2013227204402.hdf"
FDate="20130815_122404"
lat_min_index = 1262 ## -43.75S
lat_max_index = 1951 ## -42.07S

filename = "./20130907/Reff/MYD06_L2.A2013250.0435.006.2014267090313.hdf"  
filename2 = "./20130907/Reff/MYD03.A2013250.0435.006.2013250172454.hdf"
FDate="20130907_122442"
lat_min_index = 1517 ## -44.5S
lat_max_index = 2029 ## -44.2S

filename = "./20131011/Reff/MYD06_L2.A2013284.0425.006.2014268093706.hdf"  
filename2 = "./20131011/Reff/MYD03.A2013284.0425.006.2013298033119.hdf"
FDate="20131011_132432"
lat_min_index = 556 ## -44.67S
lat_max_index = 1142 ## -44.65S

filename = "./20140806/Reff/MYD06_L2.A2014218.0405.006.2014271211204.hdf"  
filename2 = "./20140806/Reff/MYD03.A2014218.0405.006.2014220175309.hdf"
FDate="20140806_150804"
lat_min_index = 1416 ## -43.51
lat_max_index = 2004 ## -42.7S

filename = "./20140903/Reff/MYD06_L2.A2014246.0430.006.2014272144020.hdf"  
filename2 = "./20140903/Reff/MYD03.A2014246.0430.006.2014246153856.hdf"
FDate="20140903_124321"
lat_min_index = 1108 ## -44.69S
lat_max_index = 1773 ## -43.34S

filename = "./20140912/Reff/MYD06_L2.A2014255.0425.006.2014282201310.hdf"  
filename2 = "./20140912/Reff/MYD03.A2014255.0425.006.2014261140010.hdf"
FDate="20140912_124317"
lat_min_index = 607 ## -44.93S
lat_max_index = 119 ## -44.28S

filename = "./20150830/Reff/MYD06_L2.A2015242.0425.006.2015243234239.hdf"  
filename2 = "./20150830/Reff/MYD03.A2015242.0425.006.2015243130645.hdf"
FDate="20150830_130524"
lat_min_index = 475   # -45.3
lat_max_index = 1195  # -43.5

filename = "./20151001/Reff/MYD06_L2.A2015274.0425.006.2015274203619.hdf"  
filename2 = "./20151001/Reff/MYD03.A2015274.0425.006.2015274154732.hdf"
FDate="20151001_123025"
lat_min_index = 465   # -44.65
lat_max_index = 1126  # -43.745
'''
### read a file
f=SD(filename)
f2=SD(filename2)

# %%
### 1) Read parameters & lat/long and 
### 2) save them to a dataframe
### 3) then save to a file for each flight

lat1 = array(f2.select('Latitude').get())
long1 = array(f2.select('Longitude').get())
SZA = array(f2.select('SolarZenith').get()) * 0.01

CTT = (array(f.select('cloud_top_temperature_1km').get())+15000)*0.01
CTH = array(f.select('cloud_top_height_1km').get()) 
CTP = array(f.select('cloud_top_pressure_1km').get()) * 0.1
CPI = array(f.select('Cloud_Phase_Infrared_1km').get())

CPOP = array(f.select('Cloud_Phase_Optical_Properties').get())
reff_16 = array(f.select('Cloud_Effective_Radius_16').get()) * 0.01 ### this works, 20130723
reff_16_PCL = array(f.select('Cloud_Effective_Radius_16_PCL').get())* 0.01
reff_21 = array(f.select('Cloud_Effective_Radius').get())* 0.01
reff_21_PCL = array(f.select('Cloud_Effective_Radius_PCL').get())* 0.01
reff_37 = array(f.select('Cloud_Effective_Radius_37').get())* 0.01
reff_37_PCL = array(f.select('Cloud_Effective_Radius_37_PCL').get())* 0.01

COT_16 = array(f.select('Cloud_Optical_Thickness_16').get())* 0.01
COT_16_PCL = array(f.select('Cloud_Optical_Thickness_16_PCL').get())* 0.01
COT_21 = array(f.select('Cloud_Optical_Thickness').get())* 0.01
COT_21_PCL = array(f.select('Cloud_Optical_Thickness_PCL').get())* 0.01
COT_37 = array(f.select('Cloud_Optical_Thickness_37').get())* 0.01
COT_37_PCL = array(f.select('Cloud_Optical_Thickness_37_PCL').get())* 0.01

CWP_16 = array(f.select('Cloud_Water_Path_16').get())
CWP_16_PCL = array(f.select('Cloud_Water_Path_16_PCL').get())
CWP_21 = array(f.select('Cloud_Water_Path').get())
CWP_21_PCL = array(f.select('Cloud_Water_Path_PCL').get())
CWP_37 = array(f.select('Cloud_Water_Path_37').get())
CWP_37_PCL = array(f.select('Cloud_Water_Path_37_PCL').get())
CMLF = array(f.select('Cloud_Multi_Layer_Flag').get())

CER_UC_16 = array(f.select('Cloud_Effective_Radius_Uncertainty_16').get())
CER_UC_21 = array(f.select('Cloud_Effective_Radius_Uncertainty').get())
CER_UC_37 = array(f.select('Cloud_Effective_Radius_Uncertainty_37').get())

### Create 3 colums of lat1, long1, and reff having 1354 X 2030 rows ----------------------------
### Because the elements of lat1 is an array (1 X 1354), to be data for dataframe, it should be converted to a list
### But to make the calculation short, it can be 450-1060 (index)

lst_lat1 = list(lat1[lat_min_index])
lst_long1 = list(long1[lat_min_index])
lst_SZA = list(SZA[lat_min_index])

lst_CTT = list(CTT[lat_min_index])
lst_CTH = list(CTH[lat_min_index])
lst_CTP = list(CTP[lat_min_index])
lst_CPI = list(CPI[lat_min_index])

lst_CPOP = list(CPOP[lat_min_index])
lst_reff_16 = list(reff_16[lat_min_index])
lst_reff_16_PCL = list(reff_16_PCL[lat_min_index])
lst_reff_21 = list(reff_21[lat_min_index])
lst_reff_21_PCL = list(reff_21_PCL[lat_min_index])
lst_reff_37 = list(reff_37[lat_min_index])
lst_reff_37_PCL = list(reff_37_PCL[lat_min_index])

lst_COT_16 = list(COT_16[lat_min_index])
lst_COT_16_PCL = list(COT_16_PCL[lat_min_index])
lst_COT_21 = list(COT_21[lat_min_index])
lst_COT_21_PCL = list(COT_21_PCL[lat_min_index])
lst_COT_37 = list(COT_37[lat_min_index])
lst_COT_37_PCL = list(COT_37_PCL[lat_min_index])

lst_CWP_16 = list(CWP_16[lat_min_index])
lst_CWP_16_PCL = list(CWP_16_PCL[lat_min_index])
lst_CWP_21 = list(CWP_21[lat_min_index])
lst_CWP_21_PCL = list(CWP_21_PCL[lat_min_index])
lst_CWP_37 = list(CWP_37[lat_min_index])
lst_CWP_37_PCL = list(CWP_37_PCL[lat_min_index])

lst_CER_UC_16 = list(CER_UC_16[lat_min_index])
lst_CER_UC_21 = list(CER_UC_21[lat_min_index])
lst_CER_UC_37 = list(CER_UC_37[lat_min_index])

lst_CMLF = list(CMLF[lat_min_index])

df = pd.DataFrame({'FDate': FDate,'lat1': lst_lat1, 'long1': lst_long1,'SZA': lst_SZA, \
                   'CTT': lst_CTT, 'CTH': lst_CTH, 'CTP': lst_CTP, 'CPI': lst_CPI, \
                   'CPOP': lst_CPOP, 'reff_16': lst_reff_16, 'reff_16_PCL': lst_reff_16_PCL, \
                   'reff_21': lst_reff_21, 'reff_21_PCL': lst_reff_21_PCL, \
                   'reff_37': lst_reff_37, 'reff_37_PCL': lst_reff_37_PCL,\
                   'COT_16': lst_COT_16, 'COT_16_PCL': lst_COT_16_PCL, \
                   'COT_21': lst_COT_21, 'COT_21_PCL': lst_COT_21_PCL, \
                   'COT_37': lst_COT_37, 'COT_37_PCL': lst_COT_37_PCL, \
                   'CWP_16': lst_CWP_16, 'CWP_16_PCL': lst_CWP_16_PCL, \
                   'CWP_21': lst_CWP_21, 'CWP_21_PCL': lst_CWP_21_PCL, \
                   'CWP_37': lst_CWP_37, 'CWP_37_PCL': lst_CWP_37_PCL, \
                   'CER_UC_16': lst_CER_UC_16,'CER_UC_21': lst_CER_UC_21,'CER_UC_37': lst_CER_UC_37,\
                   'CMLF': lst_CMLF},\
                  index=range(len(lst_lat1))) 

frames = [ df]
frames = pd.concat(frames)

#for i in range(2030-1):
for i in range(lat_max_index-lat_min_index):
    j = lat_min_index + 1 + i                ### it starts from lat_min_index + 1
    
    lst_lat1 = list(lat1[j])
    lst_long1 = list(long1[j])
    lst_SZA = list(SZA[j])

    lst_CTT = list(CTT[j])
    lst_CTH = list(CTH[j])
    lst_CTP = list(CTP[j])
    lst_CPI = list(CPI[j])

    lst_CPOP = list(CPOP[j])
    lst_reff_16 = list(reff_16[j])
    lst_reff_16_PCL = list(reff_16_PCL[j])
    lst_reff_21 = list(reff_21[j])
    lst_reff_21_PCL = list(reff_21_PCL[j])
    lst_reff_37 = list(reff_37[j])
    lst_reff_37_PCL = list(reff_37_PCL[j])

    lst_COT_16 = list(COT_16[j])
    lst_COT_16_PCL = list(COT_16_PCL[j])
    lst_COT_21 = list(COT_21[j])
    lst_COT_21_PCL = list(COT_21_PCL[j])
    lst_COT_37 = list(COT_37[j])
    lst_COT_37_PCL = list(COT_37_PCL[j])

    lst_CWP_16 = list(CWP_16[j])
    lst_CWP_16_PCL = list(CWP_16_PCL[j])
    lst_CWP_21 = list(CWP_21[j])
    lst_CWP_21_PCL = list(CWP_21_PCL[j])
    lst_CWP_37 = list(CWP_37[j])
    lst_CWP_37_PCL = list(CWP_37_PCL[j])

    lst_CER_UC_16 = list(CER_UC_16[j])
    lst_CER_UC_21 = list(CER_UC_21[j])
    lst_CER_UC_37 = list(CER_UC_37[j])

    lst_CMLF = list(CMLF[j])

    df = pd.DataFrame({'FDate': FDate,'lat1': lst_lat1, 'long1': lst_long1,'SZA': lst_SZA, \
                   'CTT': lst_CTT, 'CTH': lst_CTH, 'CTP': lst_CTP, 'CPI': lst_CPI, \
                   'CPOP': lst_CPOP, 'reff_16': lst_reff_16, 'reff_16_PCL': lst_reff_16_PCL, \
                   'reff_21': lst_reff_21, 'reff_21_PCL': lst_reff_21_PCL, \
                   'reff_37': lst_reff_37, 'reff_37_PCL': lst_reff_37_PCL,\
                   'COT_16': lst_COT_16, 'COT_16_PCL': lst_COT_16_PCL, \
                   'COT_21': lst_COT_21, 'COT_21_PCL': lst_COT_21_PCL, \
                   'COT_37': lst_COT_37, 'COT_37_PCL': lst_COT_37_PCL, \
                   'CWP_16': lst_CWP_16, 'CWP_16_PCL': lst_CWP_16_PCL, \
                   'CWP_21': lst_CWP_21, 'CWP_21_PCL': lst_CWP_21_PCL, \
                   'CWP_37': lst_CWP_37, 'CWP_37_PCL': lst_CWP_37_PCL, \
                   'CER_UC_16': lst_CER_UC_16,'CER_UC_21': lst_CER_UC_21,'CER_UC_37': lst_CER_UC_37,\
                   'CMLF': lst_CMLF},\
                  index=range(len(lst_lat1))) 
    
    frames = [ frames, df]
    frames = pd.concat(frames)
    
### Save the frames to a file
frames.to_csv('MODIS_' + FDate + '.csv', mode='w')
