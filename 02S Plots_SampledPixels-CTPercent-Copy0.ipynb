# %%
### Upgrading at 7th/Sep
### ALL 5th/Sep/2016 --------------------------------------------------------

# %%
### what this should do is ---- plot tracks and cal reff to plot reff of MODIS and aircraft
#1. get Sync_sec                    ### The exact time AC and MODIS meet
#2. Decide Target_st_sec, Target_end_sec ### For colleting AC clouds (+-15 mins)
#3. get df & df_clouds              ### input(Target_st_sec, Target_end_sec), output(df, df_clouds)
#2. get Target coordinates          ### input(target_st_time, target_end_time) output(target_coordinates)
#4. plot flight track (green & red) ### Green: whole track during the target time (get all df), Red: cloud track
                                    ### input(df,df_clouds ), output(None)
#5. Cal ac avg                      ### input(df_clouds) output(reff, etc)

#6. Cal MODIS avg                   ### input (target_coordinates) output(reff, etc)

# %%
### 1. GetSyncSec: to get Synchronized time between aircraft ad MODIS
def GetSyncSec (AC_st_time, MODIS_time):
    
    if FDate == '20130723_130219':   
        Sync_sec = 5100
    elif (FDate == "20130806_151347"):
        Sync_sec = 3800
    else:
        Start_sec = int(AC_st_time[0:2])*3600 + int(AC_st_time[2:4])*60 + int(AC_st_time[4:6])
        MODIS_time_local_sec = (int(MODIS_time[0:2])+10)*3600 + int(MODIS_time[2:4])*60 + int(MODIS_time[5:6])*6 ### seconds
        Sync_sec = MODIS_time_local_sec - Start_sec ### Synchronized time between aircraft ad MODIS
    
    print "Sync_sec : ", Sync_sec 
    
    return Sync_sec

# %%
### 2. Decide the target start and end time
def GetTargetSecs(FDate, Sync_sec, st_time_buffer, end_time_buffer):
    '''
    1) Exact time: Target_secs (6km)
    2) +- 2 ms = Target_secs + 2*60 (12km)
    3) +- 5 ms = Target_secs + 5*60 (30km)
    4) +- 10 ms = Target_secs + 10*60 (60km)
    '''
    '''
    ### for this flight, there is no clouds during MODIS overpass so decided 20 mis plus
    if (FDate == "20130614_133658" or FDate == "20140912_124317"):
        Target_st_sec = Sync_sec
        Target_end_sec = Sync_sec + 20*60  ### 20 minutes plus after MODIS overpass
    elif (FDate == "20130707_125944" or FDate == "20131011_132432"):
        Target_st_sec = Sync_sec - 15*60  
        Target_end_sec = Sync_sec + 15*60  ### 15 minutes plus minus from MODIS overpass  
    else:
        Target_st_sec = Sync_sec - 10*60  
        Target_end_sec = Sync_sec + 10*60  ### 10 minutes plus minus from MODIS overpass
    '''
    Target_st_sec  = Sync_sec - st_time_buffer*60
    Target_end_sec = Sync_sec + end_time_buffer*60  ### 15 minutes plus minus from MODIS overpass   

    print FDate, "Target_st_sec: ", Target_st_sec
    
    return Target_st_sec, Target_end_sec

# %%
def OpenNCFiles(ncname, ncname_S):
    import netCDF4

    ncfile = netCDF4.Dataset(ncname)        
    ncfile_S = netCDF4.Dataset(ncname_S)   ### SODA nc file
    
    return ncfile, ncfile_S

# %%
### define global variables----------------------------------------------------------------------
### ---------------------------------------------------------------------------------------------

import numpy as np
import netCDF4

ncname2 = "../../../../Data/2013/nc/20130614_133658.nc"
ncfile2 = netCDF4.Dataset(ncname2) 

Dp = ncfile2.groups["CAS"].variables['ForwardCounts_CAS'].getncattr('CellSizes')
    ### Dp = Diameter of a particle detected in the bin = bin size
    ### CellSizes changes by year: 2013 and 2014/2015 when Korolev Tips were equippted
Dp = np.append(Dp,50)  ### inserting the size of the last bin maximum, so len(Dp)=31, len(Rp)=30
    ### len(Dp) = 31, len(Rp) = 30
Rp = [0.]*30         
for i in range(30):
    Rp[i] = np.sqrt([Dp[i]*Dp[i+1]])*.5   ### geometric mean r in n*r^3/n*r^2 ###

###---CIP setting ----------------------------------------------------------
CIPLastBin = 20 
CIPDrizzleBin = 3 ### For discriminating drizzle ( > 125 microns) clouds' LWCCIP > 0.01 

### len(Dp_CIP) = 20, len(Rp_CIP) = 19
Dp_CIP = [62.5, 87.5, 112.5, 140, 175, 225, \
            275, 325, 400, 475, 550, \
            625, 700, 800, 900, 1000, \
            1200, 1400, 1700, 2000]

Rp_CIP = [0.]*(CIPLastBin-1)  
for i in range(CIPLastBin-1):
    Rp_CIP[i] = np.sqrt([Dp_CIP[i]*Dp_CIP[i+1]])*.5   ### geometric mean r in n*r^3/n*r^2 ###

# %%
def ReadParameters(ncfile, ncfile_S, SP):
########################################################################################################
### Get parameters for a sampling duration (RL) 
### Reff will be calcuated after filtering the condition (eg clouds) 
#########################################################################################################
    
    import pandas as pd
    
    ### Sampling duration ---------------------------------------------------------------------------------
    '''
    Range_List = [0]*len(SP) 
    SamplingPeriod = [0]*len(SP)
    for i in range(len(SP)):
        Range_List[i] = range(SP[i][0],SP[i][1])
        SamplingPeriod[i] = (SP[i][1]-SP[i][0])

    RL = Range_List[0] ### RL = the list of sampling duration ([time_start, ... .., time_end])
    '''
    RL = range(SP[0][0], SP[0][1])
    ### Read Airstate and CAS parameters ---------------------------------------------------------------------------------
    long1 = ncfile.groups["OEM4"].variables["Longitude"][RL]
    lat1 = ncfile.groups["OEM4"].variables["Latitude"][RL]#[LWC_CAS > 0.01] This part has gone to the later part

    PStat = ncfile.groups["AirState"].variables["StaticPress_Fuselage"][RL]  
    PA_FuseOEM = ncfile.groups["AirState"].variables["PressureAltitudeCorrected_Fuselage"][RL]#[LWC_CAS >0.01]
    PA_Shadin = ncfile.groups["Shadin"].variables["PressAltitude"][RL]
    TStat = ncfile.groups["AirState"].variables["AmbientTemp_TP3S"][RL]

    CDNC_Clouds= ncfile.groups["CAS"].variables["ForwardTotalConc_CAS"][RL]
    LWC_CAS= ncfile.groups["CAS"].variables["LWC_CAS"][RL]
    LWCHotWire=ncfile.groups["CAS"].variables["LWCHotWire_CAS"][RL]

    PLWC021= ncfile.groups["WCM"].variables["PLWC021"][RL]
    PLWC083= ncfile.groups["WCM"].variables["PLWC083"][RL]
    PTWC156 = ncfile.groups["WCM"].variables["PTWC156"][RL]

    MeanDia_CAS  = ncfile.groups["CAS"].variables["MeanDia_CAS"][RL]
    ### MeanDia_CIP  = ncfile.groups["CIP"].variables["MeanDia_CIP"][RL]
    Wind_Speed  = ncfile.groups["AirState"].variables["Wind_Speed"][RL]
    Wind_Direction  = ncfile.groups["AirState"].variables["Wind_Direction"][RL]
    TAS = ncfile.groups["AirState"].variables["TrueAirSpeedCorrected_TP3S"][RL]

    time = ncfile.variables["Time"][RL]

    ### Reads CIP(SODA) parameters-----------------------------------------------------------------------------------------
    MeanDia_CIP  = ncfile_S.variables["MND100"][RL]
    CIPLWC= ncfile_S.variables['LWC'][RL]
    CIPLWC_Allbins = CIPLWC
    
   ### for CIP ---------------------------------------------------------------------------------------                                                         
    CDNC_CIP_bin = ncfile_S.variables['CONCENTRATION'][:] ### [#/m^4]
    CDNC_CIP_bin = CDNC_CIP_bin.T                         ### swap the rows and columns
    CDNC_CIP_bin = CDNC_CIP_bin[RL][:]

    LWC_CIP_bin = CDNC_CIP_bin.copy()
    ary_r = ncfile_S.variables['MIDBINS'][:]/2.
        
    for i in range(len(ary_r)):
        CDNC_CIP_bin[:,i] = CDNC_CIP_bin[:,i]*(Dp_CIP[i+1]-Dp_CIP[i])*1e-12  ### Changed unit to [#/cm^3]
           ### CDNC_CIP_bin [#/cc] = [#/cm^3], Dp_CIP[1e-6m], CONCENTRATION[#/m^4]
        LWC_CIP_bin[:,i] = 4./3.*3.1415*np.power(ary_r[i],3)*CDNC_CIP_bin[:,i]*1e-6
    
    CIPLWC_Drizzle = [0.]*len(RL)
    for i in range(len(RL)):
        for j in range(CIPLastBin - CIPDrizzleBin):   ### repeat times
             CIPLWC_Drizzle[i] += LWC_CIP_bin[i][j+CIPDrizzleBin-1]
                                           

    CIPConc = ncfile_S.variables['NT'][RL]   ### number concentration [#/m^3]
    CIPConc = CIPConc*1e-6                   ### number concentration [#/cm^3]
       ### CIPTotalConc  = ncfile.groups["CIP"].variables["TotalConc_CIP"][RL] # This is for CIP concentration, all bins

    ### create df for the parameters ---------------------------------------------------------------------------------------
    df= pd.DataFrame({'Time' : time, 'PStat' : PStat,'PA_FO' : PA_FuseOEM,'PA_S' : PA_Shadin,\
                  'long1': long1,'lat1': lat1,\
                  'TStat': TStat,'CDNC' : CDNC_Clouds, 'LWCC': LWC_CAS, 'LWCHW' : LWCHotWire, \
                  'LWC021' : PLWC021, 'LWC083' : PLWC083,'TWC156' : PTWC156, \
                  'CIPLWC_Drizzle': CIPLWC_Drizzle, 'LWCCIP': CIPLWC, 'LWCCIP_All': CIPLWC_Allbins,\
                  'CIPTo' : CIPConc, 'MD': MeanDia_CAS, 'MDCIP': MeanDia_CIP, \
                  'W_S': Wind_Speed, 'W_D': Wind_Direction, 'TAS': TAS})
    return df

# %%
def GetCDNCPerBin(ncfile, ncfile_S, SP, df, Dp_CIP):
########################################################################################################
### Get CDNCperBins [#/cc] = [#/cm^3] 
### CDNCperBins is required for calulating Reff and Spectra 
#########################################################################################################
    import pandas as pd
    import numpy as np
    
    #CIPLastBin = 20
    RL = range(SP[0][0], SP[0][1])
    ### for CAS ---------------------------------------------------------------------------------------
    CDNC_bin = ncfile.groups["CAS"].variables['ForwardConc_CAS'][RL] ### CAS forward-scatter concentration, per bin
    LWC_bin = ncfile.groups["CAS"].variables['LWCPerBin_CAS'][RL] ### CAS forward-scatter concentration, per bin
    for m in range(30):
        name = 'CDNC_bin'+ np.str(m)   
        df[name] = pd.Series( CDNC_bin[:,m], index=df.index )   ### add CAS CDNCPerBin to df
        name = 'LWC_bin'+ np.str(m)
        df[name] = pd.Series( LWC_bin[:,m], index=df.index )   ### add CAS LWCPerBin to df

    ### for CIP ---------------------------------------------------------------------------------------                                                         
    CDNC_CIP_bin = ncfile_S.variables['CONCENTRATION'][:] ### [#/m^4]
    CDNC_CIP_bin = CDNC_CIP_bin.T                         ### swap the rows and columns
    CDNC_CIP_bin = CDNC_CIP_bin[RL][:]

    LWC_CIP_bin = CDNC_CIP_bin.copy()
    ary_r = ncfile_S.variables['MIDBINS'][:]/2.
    for i in range(len(ary_r)):
        CDNC_CIP_bin[:,i] = CDNC_CIP_bin[:,i]*(Dp_CIP[i+1]-Dp_CIP[i])*1e-12  ### Changed unit to [#/cm^3]
           ### CDNC_CIP_bin [#/cc] = [#/cm^3], Dp_CIP[1e-6m], CONCENTRATION[#/m^4]
        LWC_CIP_bin[:,i] = 4./3.*3.1415*np.power(ary_r[i],3)*CDNC_CIP_bin[:,i]*1e-6
           ### LWC_CIP_bin[g/m^3]

    ### add CIP_CDNCPerBin to df
    for m in range(CIPLastBin-1): 
        name = 'CDNC_CIP_bin'+ np.str(m)   
        df[name] = pd.Series( CDNC_CIP_bin[:,m], index=df.index )  
        name = 'LWC_CIP_bin'+ np.str(m)   
        df[name] = pd.Series( LWC_CIP_bin[:,m], index=df.index )
    
    return df, CDNC_bin, CDNC_CIP_bin

# %%
### Part of 3. ---------------------------------------------------------------------------------------------------
### Be careful, this one doesn't matter in or base of clouds!
def Query_forCloud(C_Flag):
    if C_Flag == 'Liq':
        #query_cloud ='(TWC156>0.01) & (LWCC+(LWCCIP-CIPLWC_Drizzle))>0.01 & (TWC156>LWC083)'  # or excluding cloud over and below
        query_cloud ='((TWC156>0.01) | (LWCC + LWCCIP)>0.01 ) & CDNC > 3' ### include cloud base and top
        #query_cloud ='(TWC156>0.005) | (LWCC + LWCCIP)>0.005' ### include cloud base and top
    elif C_Flag == 'ND':
        query_cloud ='((TWC156>0.01) | (LWCC + LWCCIP)>0.01 ) & CDNC > 3 & (CIPLWC_Drizzle<0.005)'
    elif C_Flag == 'D':
        ### CIPLWC_Drizzle ( >= 112.5) >= 0.005: is too low of drizzle         
        query_cloud ='((TWC156>0.01) | (LWCC + LWCCIP)>0.01 ) & CDNC > 3 & (CIPLWC_Drizzle>=0.005)'
    return query_cloud

# %%
def InitialFiltering(df, query1, slope, ncname):
#######################################################################################################
### Then, filter with query 1 ##########################################################################  
### df1 = after appling 1st query ###
#######################################################################################################
    import pandas as pd

    df1 = df.query(query1)  ### same as df1 = df[(df.a < df.b) & (df.b < df.c)] 
                                              ### http://pandas.pydata.org/pandas-docs/dev/indexing.html
    ### This is for calibration of WCM LWC083 ###       
    offset = 1-slope ### However, offset0.45 is the best
    df1['LWC083'] = df1['LWC083'] + offset*df1['TWC156']

    beta = 0.1*1.12
    Wi = (df1['TWC156']-df1['LWC083'])/(1.12-beta)
    Wl = (df1['TWC156']-1.12*Wi)

    df1['Wi'] = pd.Series(Wi, index=df1.index)
    df1['Wl'] = pd.Series(Wl, index=df1.index)

    ### process when Wi < 0   ### No zeroing needed
    #index_minus = df1[df1['Wi'] < 0].index.tolist()
    #df1.loc[index_minus, 'Wi'] = 0

    Mew3 = df1['Wi']/(df1['Wi']+df1['Wl'])
    df1['Mew3'] = pd.Series(Mew3, index=df1.index)    

    if ncname == '../../../../Data/2013/nc/20130723_130219.nc':
        df1['Mew3'] = pd.Series(0, index=df1.index) 
    else:
        df1['Mew3'] = pd.Series(Mew3, index=df1.index)  
    
    return df1

# %%
def CalReff_CAS(CDNC_bin, df1, Dp, Rp):
###########################################################################################################
#### Reff: is calculated for the index item from df1 (after filtering) 
###########################################################################################################

    import numpy as np
    import pandas as pd

    #RL = range(SP[0][0], SP[0][1])
    #CDNC_bin = ncfile.groups["CAS"].variables['ForwardConc_CAS'][RL] ### Range_List[0] = RL  ######
    R_eff_Sec = [np.NaN] * len(df1.index)  ### List, only for the NECESSARY length, not len(Range_List[0]) ###
    Child_Sec = [np.NaN] * len(df1.index)
    Parent_Sec = [np.NaN] * len(df1.index)
    N_bin = [0.]*30  ### total N for RL for each bin, for only Spectra
    NoOfTime = 0   ### for only Spectra

    for j in range(len(df1.index)):   ### only creates for the effective rows from df5 ###    
        k = df1.index[j]
        Child_Sec[j]  = 0.
        Parent_Sec[j]  = 0.
        for m in range(30):
            a = np.float(CDNC_bin[k][m]*pow(Rp[m],3))      ### change array to float, otherwise ###
                                                       ### Child_Sec[j]:array,(BUT Child_Sec: array list) ###
            Child_Sec[j] = a + Child_Sec[j]  
            b = np.float(CDNC_bin[k][m]*np.square(Rp[m]))
            Parent_Sec[j] = b + Parent_Sec[j]
            #N_bin[m] += CDNC_bin[k][m]   ### For only Spectra ###
        NoOfTime = NoOfTime +1       ### For only Spectra ###
        if Parent_Sec[j] <> 0:       ### added on 14/Sep/2015
            R_eff_Sec[j] = Child_Sec[j]/Parent_Sec[j]    ### This division only possible with array ###

    ### create and append the Reff row to df1 -------------------------------------------------------
    df1['Reff'] = pd.Series(R_eff_Sec, index=df1.index)   

    ### For Spectra (CAS) ------------------------------------------------------------------------------------

    #Spectrum = [0.]*31
    Spectrum = [np.NaN]*31
    AvgN_bin = [0.]*30
    
    for i in range(30):
        if NoOfTime <> 0:
            AvgN_bin[i] = N_bin[i]/NoOfTime  ### AvgN_bin = dN

    #Spectrum[0] = 0  ### for Step plot, making the y[0] = 0 ###
    for i in range(30):
         Spectrum[i+1] = AvgN_bin[i]/(np.log10(Dp[i+1])-np.log10(Dp[i]))  ### dN/dLogDp, dN = AvgN_bin

    return df1, Spectrum

# %%
def CalReff_Total(CDNC_bin, CDNC_CIP_bin, df1, Rp, Dp_CIP, Rp_CIP):
###########################################################################################################
#### Reff_Total including CIP 
###########################################################################################################

    import numpy as np
    import pandas as pd
    
    #CIPLastBin = 20
    
    R_eff_Total_Sec = [np.NaN] * len(df1.index)  ### List, only for the NECESSARY length, not len(Range_List[0]) ###
    Child_Sec = [np.NaN] * len(df1.index)
    Parent_Sec = [np.NaN] * len(df1.index)
    N_bin = [0.]*30  ### total N for RL for each bin, for only Spectra
    NoOfTime = 0   ### for only Spectra
    N_CIP_bin = [0.]*(CIPLastBin-1)  ### Redefine N_CIP_bin for Spectra (1st bin ~ CIPLastBin bin) only

    for j in range(len(df1.index)):   ### only creates for the effective rows from df5 ###    
        k = df1.index[j]
        Child_Sec[j]  = 0.
        Parent_Sec[j]  = 0.

        for m in range(30):
            a = np.float(CDNC_bin[k][m]*pow(Rp[m],3))      ### change array to float, otherwise ###
                                                       ### Child_Sec[j]:array,(BUT Child_Sec: array list) ###
            Child_Sec[j] = a + Child_Sec[j]  
            b = np.float(CDNC_bin[k][m]*np.square(Rp[m]))
            Parent_Sec[j] = b + Parent_Sec[j]
            N_bin[m] += CDNC_bin[k][m]   ### For Spectra only ###

        for m in range(CIPLastBin-1):  ### repeat 31 times for Reff_Total, 3rd~33rd bins (33-3+1)
            a2 = np.float(CDNC_CIP_bin[k][m]*pow(Rp_CIP[m],3))      ### change array to float, otherwise ###
                                                       ### Child_Sec[j]:array,(BUT Child_Sec: array list) ###
            Child_Sec[j] = a2 + Child_Sec[j]  
            b2 = np.float(CDNC_CIP_bin[k][m]*np.square(Rp_CIP[m]))
            Parent_Sec[j] = b2 + Parent_Sec[j]
            N_CIP_bin[m] += CDNC_CIP_bin[k][m]   ### For Spectra only, so uncomment if you want to calculate for spectra###        
        NoOfTime = NoOfTime +1       ### For Spectra only, so uncomment if you want to calculate for spectra ###
        if Parent_Sec[j] <> 0:
            R_eff_Total_Sec[j] = Child_Sec[j]/Parent_Sec[j]    ### This division only possible with array ###

    ################## create and append the Reff row to df1 #############################################
    df1['Reff_Total'] = pd.Series(R_eff_Total_Sec, index=df1.index)  

    
    #### For Spectra (CIP) ##############################################################################
    ### N_CIP_bin & NoOfTime needs to calculate #########################################################

    #CDNC_CIP_bin = ncfile.groups["CIP"].variables['Conc_CIP'][RL] ### CIP concentration, per bin

    for j in range(len(df1.index)):   ### only creates for the effective rows from df5 ###    
        k = df1.index[j]
        for m in range(CIPLastBin-1):
            N_CIP_bin[m] += CDNC_CIP_bin[k][m]   ### For Spectra only from the 1st bin###
        NoOfTime = NoOfTime +1       ### For Spectra only ###

    Spectrum_CIP = [np.NaN]*(CIPLastBin-1)
    AvgN_CIP_bin = [0.]*(CIPLastBin-1)
    for i in range(CIPLastBin-1):  
        if NoOfTime <> 0:
            AvgN_CIP_bin[i] = N_CIP_bin[i]/NoOfTime   ### AvgN_CIP_bin = dN 

    #Spectrum_CIP[0] = 0  ### for Step plot, making the y[0] = 0 ###
    for i in range(CIPLastBin-1): 
        Spectrum_CIP[i] = AvgN_CIP_bin[i]/(np.log10(Dp_CIP[i+1])-np.log10(Dp_CIP[i]))  ### dN/dLogDp, dN = AvgN_CIP_bin
    
    return df1, Spectrum_CIP

# %%
def GetLiq_df3(df1, ncname):
########################################################################################################
### Get liquid clouds and Quality control   
########################################################################################################
    import pandas as pd
    import numpy as np

    ### Get liquid clouds -------------------------------------------------------------------------------
    if ncname == '../../../Data/2013/nc/20130723_130219.nc':### For 0723, couldn't create Mew3 because of WCM no working
        df_Liq2 = df1
    else:                 
        df_Liq2 = df1.query('(Mew3 <= 0.1 | TStat >= 0)')   ### New (10/Nov/2015) 
        ###df_Liq2 = df1.query('Mew3 > 0.1 & TStat <= 0')   ### for mixed phase clouds
        '''### the following is not applied when using SODA
        #### This is for deleting LWC CAPS outliers ########################################################
        SD = (df_Liq2['TWC156']-(df_Liq2['LWCC']+df_Liq2['LWCCIP'])).std()
        dftemp = df_Liq2[(df_Liq2['LWCC'] + df_Liq2['LWCCIP']- df_Liq2['TWC156']) > 2*SD]
        index01 = df_Liq2.index.tolist()
        index02 = dftemp.index.tolist()
        minus = list(set(index01) - set(index02))
        df_Liq2 = df_Liq2.loc[minus]
        #################################################################################################
        '''

    df3 = df_Liq2   ### Need to separate df_Liq2 from df3 ### IMportant !!! #####################

    df3.PStat = np.round (np.round(df3.PStat,-1)/10)*10 ### making the height as 10hPa unit eg. 762hPa => 760 ###

    ###--------------Adding in additional info. to df3 for analysis -----------------------------------   
    df3['TWCCAPS'] = pd.Series( df3['LWCC']+df3['LWCCIP'], index=df3.index ) ### this should be added to get std. of TWCCAPS
    df3['FDate'] = pd.Series( ncname[22:37], index=df3.index )   
    #df3['FType'] = pd.Series( FType, index=df3.index )          
    df3['Mon'] = pd.Series( int(ncname[26:28]), index=df3.index )

    return df3

# %%
def GetAvg_df4(df3, FDate):
### Creating df4 #####################################################################################
    ###del df3['Time']

    import pandas as pd
    import numpy as np

    df4= df3.groupby('PStat').mean()    

    ### Formatting ##################################################################
    df4.PA_FO = np.round(df4.PA_FO ,0) ; df4.PA_S = np.round(df4.PA_S,0)
    df4.lat1 = np.round(df4.lat1,1) ; df4.TStat = np.round(df4.TStat,1); df4.long1 = np.round(df4.long1,1) ;
    df4.CDNC = np.round(df4.CDNC,1) ; df4.Reff = np.round(df4.Reff,1); df4.Reff_Total = np.round(df4.Reff_Total,1)

    df4.LWCC = np.round(df4.LWCC,3) ; df4.LWCHW = np.round(df4.LWCHW,3)
    df4.LWC021 = np.round(df4.LWC021,3) ; df4.LWC083 = np.round(df4.LWC083,3)
    df4.LWCCIP = np.round(df4.LWCCIP,3) ; df4.LWCCIP_All = np.round(df4.LWCCIP_All,3)
    df4.TWC156 = np.round(df4.TWC156,3) ; df4.TWCCAPS = np.round(df4.TWCCAPS,3); df4.Mew3 = np.round(df4.Mew3,2)

    df4.MD = np.round(df4.MD,1) ;df4.CIPTo = np.round(df4.CIPTo,2);df4.MDCIP = np.round(df4.MDCIP,1)
    df4.W_S = np.round(df4.W_S,0) ;df4.W_D = np.round(df4.W_D,0); df4.TAS = np.round(df4.TAS,0)

    df4['PStat2'] = pd.Series(np.unique(df3['PStat']), index=df4.index) ### Because PStat is needed to plot, having PStat as
                                                            ### a column is needed. 
    df4['Count'] = pd.Series(df3.groupby('PStat').count()['LWCHW'], index=df4.index)  ### adding count
    #df4 = df4.query('CDNC > 1')
    df4['std_CDNC'] = pd.Series((df3.groupby('PStat').std())['CDNC'], index=df4.index)
    df4['std_CIPTo'] = pd.Series((df3.groupby('PStat').std())['CIPTo'], index=df4.index)
    df4['std_Reff'] = pd.Series((df3.groupby('PStat').std())['Reff'], index=df4.index)
    df4['std_ReffT'] = pd.Series((df3.groupby('PStat').std())['Reff_Total'], index=df4.index)
    df4['std_LWCC'] = pd.Series((df3.groupby('PStat').std())['LWCC'], index=df4.index)
    df4['std_LWCCIP'] = pd.Series((df3.groupby('PStat').std())['LWCCIP'], index=df4.index)
    df4['std_TWCCAPS'] = pd.Series((df3.groupby('PStat').std())['TWCCAPS'], index=df4.index)
    df4['FDate'] = pd.Series(FDate, index=df4.index)

    return df4

# %%
###3. get df & df_clouds              ### input(Target_st_sec, Target_end_sec), output(df, df_clouds)
def Get_dfNdf_clouds (FDate, Target_st_sec, Target_end_sec, query1, slope, ncname_S):

    import netCDF4
    import pandas as pd
    
    if FDate[0:4] == '2013':
        ncname = "../../../../Data/2013/nc/" + FDate + ".nc"  
    elif FDate[0:4] == '2014':
        ncname = "../../../../Data/2014/nc/" + FDate + ".nc"
    elif FDate[0:4] == '2015':
        ncname = "../../../../Data/2015/nc/" + FDate + ".nc"
        
    SP = [[Target_st_sec,Target_end_sec]]
    
    ### Start of df_clouds ---------------------------------------------------------
    ncfile, ncfile_S = OpenNCFiles(ncname, ncname_S)
    df = ReadParameters(ncfile, ncfile_S, SP)
    df, CDNC_bin, CDNC_CIP_bin = GetCDNCPerBin(ncfile, ncfile_S, SP, df, Dp_CIP)
    df1 = InitialFiltering(df, query1, slope, ncname)
    
    df1, Spectrum = CalReff_CAS(CDNC_bin, df1, Dp, Rp)
    df1, Spectrum_CIP = CalReff_Total(CDNC_bin, CDNC_CIP_bin, df1, Rp, Dp_CIP, Rp_CIP)
    df_clouds = GetLiq_df3(df1, ncname)
    df4 = GetAvg_df4(df_clouds, FDate)
    
    print "len(df): ", len(df), ", len(df_clouds): ", len(df_clouds)
    
    return df, df_clouds, df4

# %%
def Rain_Rate(df3):
    
    import dropvel ### import python object originally scripted by Fortran ## 01/Jul/2016
    
    df=df3

    rhow=1e3
    pi = 3.1415926
    presPa = np.array(df['PStat']*100.)   ### PStat: hPa
    # PDynamic = np.array(df['PDynamic']*100.) ### PDynamic: hPa, no need as drops spend more time in static pressure
    # APress = presPa + PDynamic ### no need as drops spend more time in static pressure
    tempK = np.array(df['TStat']+273.16)
    rhoakgm3 = np.array(df['TWCCAPS'])
    #PVapor = np.array(df['PVapor']) ### PVapor'unit: Pascal, partial water vapor pressure, no need as drops drop in dry air

    ''' This is Thom's code
    #dropradsm = ['Dp_CIP']/2.
    #c2dca = df3['CDNC_CIP_bin'][5:33]
    #CDNC_CIP_bin = ncfile.groups["CIP"].variables['Conc_CIP'][RL]
    #RainRate2DC(presPa,tempK,rhoakgm3,dropradsm,c2dca)
    #dropvel.term_vel_bp(1e-4, 100000,273,1.22) ### (radius, pressure, temp, rho)
                                           ### e-6, X 100, 273+ , mass/volume (kg/m^3)
    '''
    Rd = 287.058 #Specific gas constant for dry air J/(kg*K)
    #Rv = 461.495
    #Lv = 2.501*1e6
    #Cpd = 1005.7
    #g = 9.80
    #sigma = 72.73e-3
    
    ary_RR = [0]*len(df)
    rhoa = [0]*len(df)
    for j in range(len(df)):
        RR = 0.
        #rhoa[j] = ( presPa[j]-PVapor[j] )/(Rd*tempK[j]) + PVapor[j]/(Rv*tempK[j]) ### Vivian used this with water vapor pressure
                                                                            ### But I used below as drops will drop through dry air
        rhoa[j] = presPa[j]/(Rd*tempK[j])  ### simple dry air density
                                           ### http://www.brisbanehotairballooning.com.au/calculate-air-density/
        for i in range(19):  ### Dp_CIP starts with 62.5 microns
            r_median = (Dp_CIP[i] + (Dp_CIP[i+1]-Dp_CIP[i])/2.)/2.*1e-6 ### radius, unit [meter]            
            tv = dropvel.term_vel_bp(r_median, presPa[j], tempK[j], rhoa[j]) ### terminal velocity or drop fall speed [m/sec]
            RR += rhow*(4./3)*pi*r_median**3*df.at[df.index[j],'CDNC_CIP_bin'+np.str(i)]*1e6*tv # Be careful for the grammer
        ary_RR[j] = RR*3600
        
    return np.average(ary_RR)

# %%
### End of AC processing an START of MODIS ########################################################

# %%
km = '05km'
print km[0:2], type(float(km[0:2]))
# Out:
# 05 <type 'float'>

# %%
### 5. Retrieve Reff for the coordinates from the existing MODIS file and compare this to AC's Reff
#def Get_MODISReff(FDate, df, km):
import numpy as npMODIS_reff_
import pandas as pd

### Get coordinates from the existing MODIS file -----------------------------------
df_MODIS = pd.read_csv('MODIS_'+ FDate + '.csv')     ### Read(Get) MODIS data
#df_MODIS['CTT'] = (df_MODIS['CTT']/0.009999+15000)*0.01-273.15
df_MODIS['CTT'] = df_MODIS['CTT']-273.15

if (FDate == "20130806_151347" ):     ### manually estimated 
    df_lat_min  = -43.05; df_lat_max  = -42.35
    df_long_min = 143.6 ; df_long_max = 143.65
elif (FDate == "20130723_130219" ): 
    df_lat_min  = -44.7; df_lat_max  = -43.9
    df_long_min = 146.8 ; df_long_max = 147.1
else:
    df_lat_min  = df['lat1'].min()  ; df_lat_max  = df['lat1'].max()
    df_long_min = df['long1'].min() ; df_long_max = df['long1'].max()   

lat_min  = str( df_lat_min  - 0.01*float(km[0:2]) ) ### 1 degree = 100km, 0.05 = 5km
lat_max  = str( df_lat_max  + 0.01*float(km[0:2]) )
long_min = str( df_long_min - 0.01*float(km[0:2]) )
long_max = str( df_long_max + 0.01*float(km[0:2]) )    

query_Liq = 'lat1 <'+lat_max+' & lat1 >'+lat_min+'& long1 >'+long_min+'& long1 <'+long_max+'& reff_16 > 0 & CPOP == 2'                                                                                
df_MODIS_16 = df_MODIS.query(query_Liq)  ### MODIS reff default = 1km
query_Liq = 'lat1 <'+lat_max+' & lat1 >'+lat_min+'& long1 >'+long_min+'& long1 <'+long_max+'& reff_21 > 0 & CPOP == 2'                                                                                
df_MODIS_21 = df_MODIS.query(query_Liq)  
query_Liq = 'lat1 <'+lat_max+' & lat1 >'+lat_min+'& long1 >'+long_min+'& long1 <'+long_max+'& reff_37 > 0 & CPOP == 2'                                                                                
df_MODIS_37 = df_MODIS.query(query_Liq)  

query_Liq = 'lat1 <'+lat_max+' & lat1 >'+lat_min+'& long1 >'+long_min+'& long1 <'+long_max+'& reff_16_PCL > 0 & CPOP == 2'                                                                                
df_MODIS_16_PCL = df_MODIS.query(query_Liq)  ### MODIS reff default = 1km
query_Liq = 'lat1 <'+lat_max+' & lat1 >'+lat_min+'& long1 >'+long_min+'& long1 <'+long_max+'& reff_21_PCL > 0 & CPOP == 2'                                                                                
df_MODIS_21_PCL = df_MODIS.query(query_Liq)  
query_Liq = 'lat1 <'+lat_max+' & lat1 >'+lat_min+'& long1 >'+long_min+'& long1 <'+long_max+'& reff_37_PCL > 0 & CPOP == 2'                                                                                
df_MODIS_37_PCL = df_MODIS.query(query_Liq) 

print lat_min, lat_max, long_min, long_max
print "len(16): ", len(df_MODIS_16), " len(16_PCL): ", len(df_MODIS_16_PCL)
print "len(21): ", len(df_MODIS_21), " len(21_PCL): ", len(df_MODIS_21_PCL)
print "len(37): ", len(df_MODIS_37), " len(37_PCL): ", len(df_MODIS_37_PCL)

    #return df_MODIS_16, df_MODIS_21, df_MODIS_37,df_MODIS_16_PCL, df_MODIS_21_PCL, df_MODIS_37_PCL
# Out:
# -43.9340555217 -43.28544212 147.930269013 148.66641782
# len(16):  921  len(16_PCL):  346
# len(21):  2010  len(21_PCL):  1147
# len(37):  2008  len(37_PCL):  1154

# %%
df_MODIS_21[0:10]
# Out:
#         Unnamed: 0  CER_UC_16  CER_UC_21  CER_UC_37  CMLF  COT_16  COT_16_PCL  \
# 540760         514      -9999        439        570     1  -99.99      -99.99
# 542114         514      -9999        468        561     1  -99.99      -99.99
# 542115         515      -9999        459        574     1  -99.99      -99.99
# 542116         516      -9999        433        594     1  -99.99      -99.99
# 542117         517      -9999        448        610     1  -99.99      -99.99
# 542118         518      -9999        504        570     1  -99.99      -99.99
# 543467         513      -9999        454        599     1  -99.99      -99.99
# 543468         514      -9999        459        561     1  -99.99      -99.99
# 543469         515      -9999        410        578     1  -99.99      -99.99
# 543470         516      -9999        461        564     1  -99.99      -99.99
#
#         COT_21  COT_21_PCL  COT_37  COT_37_PCL  CPI  CPOP   CTH  CTP   CTT  \
# 540760   19.50      -99.99   19.32      -99.99    1     2  2650  730 -3.16
# 542114   19.05      -99.99   19.01      -99.99    1     2  2650  730 -3.16
# 542115   12.37      -99.99   12.17      -99.99    1     2  2650  730 -3.16
# 542116   21.53      -99.99   21.49      -99.99    1     2  2650  730 -3.16
# 542117   17.40      -99.99   17.28      -99.99    1     2  2650  730 -3.16
# 542118   11.53      -99.99   11.36      -99.99    1     2  2400  755 -1.71
# 543467   12.80      -99.99   12.65      -99.99    1     2  2650  730 -3.16
# 543468   10.10      -99.99   10.04      -99.99    1     2  2650  730 -3.16
# 543469   15.82      -99.99   15.72      -99.99    1     2  2650  730 -3.16
# 543470   36.14      -99.99   36.75      -99.99    1     2  2650  730 -3.16
#
#         CWP_16  CWP_16_PCL  CWP_21  CWP_21_PCL  CWP_37  CWP_37_PCL  \
# 540760   -9999       -9999     290       -9999     270       -9999
# 542114   -9999       -9999     215       -9999     212       -9999
# 542115   -9999       -9999     183       -9999     159       -9999
# 542116   -9999       -9999     314       -9999     310       -9999
# 542117   -9999       -9999     220       -9999     208       -9999
# 542118   -9999       -9999     126       -9999     113       -9999
# 543467   -9999       -9999     187       -9999     170       -9999
# 543468   -9999       -9999     162       -9999     154       -9999
# 543469   -9999       -9999     236       -9999     225       -9999
# 543470   -9999       -9999     414       -9999     468       -9999
#
#                   FDate    SZA       lat1       long1  reff_16  reff_16_PCL  \
# 540760  20130614_133658  74.08 -43.933990  148.657104   -99.99       -99.99
# 542114  20130614_133658  74.07 -43.924770  148.654160   -99.99       -99.99
# 542115  20130614_133658  74.06 -43.926937  148.640976   -99.99       -99.99
# 542116  20130614_133658  74.06 -43.929100  148.627777   -99.99       -99.99
# 542117  20130614_133658  74.06 -43.931259  148.614609   -99.99       -99.99
# 542118  20130614_133658  74.05 -43.933414  148.601440   -99.99       -99.99
# 543467  20130614_133658  74.06 -43.913376  148.664429   -99.99       -99.99
# 543468  20130614_133658  74.06 -43.915546  148.651230   -99.99       -99.99
# 543469  20130614_133658  74.05 -43.917717  148.638046   -99.99       -99.99
# 543470  20130614_133658  74.05 -43.919884  148.624863   -99.99       -99.99
#
#         reff_21  reff_21_PCL  reff_37  reff_37_PCL
# 540760    22.96       -99.99    21.56       -99.99
# 542114    17.52       -99.99    17.32       -99.99
# 542115    22.80       -99.99    20.23       -99.99
# 542116    22.55       -99.99    22.31       -99.99
# 542117    19.55       -99.99    18.61       -99.99
# 542118    17.02       -99.99    15.50       -99.99
# 543467    22.57       -99.99    20.84       -99.99
# 543468    24.79       -99.99    23.60       -99.99
# 543469    23.04       -99.99    22.05       -99.99
# 543470    17.75       -99.99    19.70       -99.99

# %%
######################################################################################################
### Main script ######################################################################################
import pandas as pd

#C_Flag = 'Liq'
#df_FInfo= pd.read_csv('Flight_info2.csv')

#km = '10km'
#km = '05km'
km = '10km'


### (1) ------------------------------------------
FDate = "20130614_133658"; AC_st_time = '133658'
#MODIS_Time = '0421.6' ### This should be saved in the FlightInfo, and should be provide this form including decimal
MODIS_Time = '0420.0'
query1 = '(lat1 < -43.) & '+ Query_forCloud('Liq')
queryD = '(lat1 < -43.) & '+ Query_forCloud('D')
slope = 0.732
M_fname1 = "./20130614/Reff/MYD06_L2.A2013165.0420.006.2014266205611.hdf"
M_fname2 = "./20130614/Reff/MYD03.A2013165.0420.006.2013165155508.hdf"
ncname_S = '../SODA/SODA_nc/06142013_133659_CIP10.nc' ## 
reff_x = 60; Press_y = 750;  lgnd_loc = "upper right"; lgnd_loc2 = "upper left"
st_time_buffer = 0; end_time_buffer = 30   ### should be end_time_buffer = 30
loc_bm = [-46, -41.5, 144.5, 149]
'''
### (2) ------------------------------------------
FDate = "20130628_130139"
AC_st_time = FDate[9:15]; MODIS_Time = '0434.0'   
#query_part = df_FInfo[df_FInfo.query('F_date == '+FDate)]['Query1']
#query1 = query_part + Query_forCloud(C_Flag) 
query1 = '(lat1 < -43.5 | long1 < 146) & '+ Query_forCloud('Liq') ### for long1<145.4, the result is same 
slope = 0.720
M_fname1 = "./20130628/Reff/MYD06_L2.A2013179.0430.006.2014267001301.hdf"
M_fname2 = "./20130628/Reff/MYD03.A2013179.0430.006.2013179161739.hdf"
ncname_S = '../SODA/SODA_nc/06282013_130141_CIP10.nc'
queryD = '(lat1 < -43.5 | long1 < 146) & '+ Query_forCloud('D')
reff_x = 60; Press_y = 750;  lgnd_loc = "upper right"; lgnd_loc2 = "upper left"
st_time_buffer = 15; end_time_buffer = 15
loc_bm = [-46, -41.5, 144.5, 149]

### (3) ------------------------------------------
FDate = "20130707_125944"
AC_st_time = '125944'
MODIS_Time = '0428.0' ### This should be saved in the FlightInfo, and should be provide this form including decimal
query1 = '(lat1 < -43.5 & long1 < 147.5) & '+ Query_forCloud('Liq')
slope = 0.678
M_fname1 = "./20130707/Reff/MYD06_L2.A2013188.0425.006.2014267025147.hdf"
M_fname2 = "./20130707/Reff/MYD03.A2013188.0425.006.2013188151355.hdf"
ncname_S = '../SODA/SODA_nc/07072013_073754_CIP10.nc'
queryD = '(lat1 < -43.5 & long1 < 147.5) & '+ Query_forCloud('D')
reff_x = 60; Press_y = 750;  lgnd_loc = "lower right"; lgnd_loc2 = "upper right"
st_time_buffer = 15; end_time_buffer = 15
loc_bm = [-46, -41.5, 144.5, 149]

### (4) ------------------------------------------
FDate = "20130723_130219"
AC_st_time = FDate[9:15]; MODIS_Time = '0427.8'  
F_Desc = "Research"
query1 = '(LWCC+LWCCIP > 0.01) & CDNC > 3'
slope = 0.75
M_fname1 = "./20130723/Reff/MYD06_L2.A2013204.0425.006.2014267101648.hdf"  
M_fname2 = "./20130723/Reff/MYD03.A2013204.0425.006.2013205024031.hdf"
ncname_S = '../SODA/SODA_nc/07232013_130221_CIP10.nc'
queryD = '(LWCC+LWCCIP > 0.01) & CDNC > 3 & LWCCIP > 0.005'
reff_x = 60; Press_y = 750;  lgnd_loc = "center right"; lgnd_loc2 = "upper right"
st_time_buffer = 15; end_time_buffer = 15
loc_bm = [-46, -41.5, 144.5, 149]

### (5) ------------------------------------------
FDate = "20130806_151347" ### AC flew after MODIS overpass  
AC_st_time = FDate[9:15]; MODIS_Time = '0440.0'
F_Desc = "Research"
query1 = '(long1 < 145.5 & lat1 < -42.1) & '+ Query_forCloud('Liq')
slope = 0.75
M_fname1 = "./20130806/Reff/MYD06_L2.A2013218.0440.006.2014267174320.hdf" ### AC flew after overpass
M_fname2 = "./20130806/Reff/MYD03.A2013218.0440.006.2013218171157.hdf"
ncname_S = '../SODA/SODA_nc/08062013_151349_CIP10.nc'
queryD = '(long1 < 145.5 & lat1 < -42.1) & '+ Query_forCloud('D')
reff_x = 60; Press_y = 750;  lgnd_loc = "lower right"; lgnd_loc2 = "upper right"
st_time_buffer = 10; end_time_buffer = 20
loc_bm = [-46, -41.5, 142,145.5]

### (6) ------------------------------------------
FDate = "20130815_122404" 
AC_st_time = FDate[9:15]; MODIS_Time = '0434.0'   
F_Desc = "Research, Non-Baseline, Ocean(W=>SW), Prefrontal(middle), Not MCC"
query1 = '(long1 < 145.2 | lat1 < -43.6) & '+ Query_forCloud('Liq')
slope = 0.881
M_fname1 = "./20130815/Reff/MYD06_L2.A2013227.0430.006.2014267173440.hdf"  
M_fname2 = "./20130815/Reff/MYD03.A2013227.0430.006.2013227204402.hdf"
ncname_S = '../SODA/SODA_nc/08152013_122405_CIP10.nc'
queryD = '(long1 < 145.2 | lat1 < -43.6) & '+ Query_forCloud('D')
reff_x = 60; Press_y = 700;  lgnd_loc = "lower right"; lgnd_loc2 = "upper right"
st_time_buffer = 15; end_time_buffer = 15
loc_bm = [-46, -41.5, 142.5, 147]

### (7) ------------------------------------------
FDate = "20130907_122442"
AC_st_time = FDate[9:15]; MODIS_Time = '0439.0'   
query1 = '(long1 < 145.6 | lat1 < -43.3) & '+ Query_forCloud('Liq')
slope = 0.538
M_fname1 = "./20130907/Reff/MYD06_L2.A2013250.0435.006.2014267090313.hdf"  
M_fname2 = "./20130907/Reff/MYD03.A2013250.0435.006.2013250172454.hdf"
ncname_S = '../SODA/SODA_nc/07072013_073754_CIP10.nc'
queryD = '(long1 < 145.6 | lat1 < -43.3) & '+ Query_forCloud('D')
reff_x = 60; Press_y = 750;  lgnd_loc = "lower right"; lgnd_loc2 = "upper right"
st_time_buffer = 20; end_time_buffer = 10  ### end_time_buffer should be 10
loc_bm = [-46, -41.5, 144.5, 149]

### (8) ------------------------------------------
FDate = "20131011_132432"
AC_st_time = '132432'; MODIS_Time = '0427.6'  
query1 = '(lat1 < -43.5) & '+ Query_forCloud('Liq')
slope = 0.799
M_fname1 = "./20131011/Reff/MYD06_L2.A2013284.0425.006.2014268093706.hdf"
M_fname2 = "./20131011/Reff/MYD03.A2013284.0425.006.2013298033119.hdf"
ncname_S = '../SODA/SODA_nc/10112013_132433_CIP10.nc'
queryD = '(lat1 < -43.5) & '+ Query_forCloud('D')
reff_x = 60; Press_y = 500;  lgnd_loc = "lower right"; lgnd_loc2 = "upper right"
st_time_buffer = 15; end_time_buffer = 15
loc_bm = [-46, -41.5, 144.5, 149]

### (9) NOT included ------------------------------------------
FDate="20140806_150804"   ### Seeding flight
AC_st_time = '150804' ; MODIS_Time = '0409.0'
query1 ='(lat1 < -43 ) & '+ Query_forCloud('Liq')
slope = 0.75
M_fname1 = "./20140806/Reff/MYD06_L2.A2014218.0405.006.2014271211204.hdf"  
M_fname2 = "./20140806/Reff/MYD03.A2014218.0405.006.2014220175309.hdf"
ncname_S = '../SODA/SODA_nc/08062014_150806_CIP7.nc'
query1 ='(lat1 < -43 ) & '+ Query_forCloud('D')
reff_x = 60; Press_y = 500;  lgnd_loc = "lower right"

### (10) ------------------------------------------
FDate="20140903_124321"
AC_st_time = '124321' ; MODIS_Time = '0434.0'
query1 ='((long1 < 146 & lat1 < -43.3 ) | lat1 < -43.5 ) & '+ Query_forCloud('Liq')
slope = 0.774
M_fname1 = "./20140903/Reff/MYD06_L2.A2014246.0430.006.2014272144020.hdf"  
M_fname2 = "./20140903/Reff/MYD03.A2014246.0430.006.2014246153856.hdf"
ncname_S = '../SODA/SODA_nc/09032014_124323_CIP7.nc'
queryD='((long1 < 146 & lat1 < -43.3 ) | lat1 < -43.5 ) & '+ Query_forCloud('D')
reff_x = 60; Press_y = 650;  lgnd_loc = "center right"; lgnd_loc2 = "upper right"
st_time_buffer = 15; end_time_buffer = 15
loc_bm = [-46, -41.5, 144.5, 149]

### (11) ------------------------------------------
FDate="20140912_124317"
AC_st_time = '124317' ; MODIS_Time = '0427.7'
query1 ='lat1 < -43.7 & '+ Query_forCloud('Liq')
slope = 0.744
M_fname1 = "./20140912/Reff/MYD06_L2.A2014255.0425.006.2014282201310.hdf"  
M_fname2 = "./20140912/Reff/MYD03.A2014255.0425.006.2014261140010.hdf"
ncname_S = '../SODA/SODA_nc/09122014_124319_CIP7.nc'
query1 ='lat1 < -43.7 & '+ Query_forCloud('D')
reff_x = 60; Press_y = 700;  lgnd_loc = "lower right"; lgnd_loc2 = "upper right"
st_time_buffer = 0; end_time_buffer = 30
loc_bm = [-46, -41.5, 144.5, 149]

### (12) ------------------------------------------
FDate = "20150830_130524"
AC_st_time = '130525'
MODIS_Time = '0426.0'   ### should be provide this form including decimal
F_Desc = "Research, Baseline, Ocean(S), Not associated, Open MCC"
query1 = 'lat1 < -43.7 & '+ Query_forCloud('Liq') ### for long1<145.4, the result is same 
slope = 0.535
M_fname1 = "./20150830/Reff/MYD06_L2.A2015242.0425.006.2015243234239.hdf"
M_fname2 = "./20150830/Reff/MYD03.A2015242.0425.006.2015243130645.hdf"
ncname_S = '../SODA/SODA_nc/08302015_130525_CIP7.nc'
queryD = 'lat1 < -43.7 & '+ Query_forCloud('D')
reff_x = 60; Press_y = 750;  lgnd_loc = "upper right"; lgnd_loc2 = "upper left"
st_time_buffer = 15; end_time_buffer = 15
loc_bm = [-46, -41.5, 144.5, 149]

### (13) ------------------------------------------
FDate = "20151001_123025"
AC_st_time = FDate[9:15]
MODIS_Time = '0427.5'   ### should be provide this form including decimal
F_Desc = "Research"
query1 = '(lat1 < -43.6 ) & '+ Query_forCloud('Liq')
slope = 0.783
M_fname1 = "./20151001/Reff/MYD06_L2.A2015274.0425.006.2015274203619.hdf"  
M_fname2 = "./20151001/Reff/MYD03.A2015274.0425.006.2015274154732.hdf"
ncname_S = '../SODA/SODA_nc/10012015_123026_CIP7.nc'
queryD = '(lat1 < -43.6 ) & '+ Query_forCloud('D')
reff_x = 60; Press_y = 750;  lgnd_loc = "upper right"; lgnd_loc2 = "upper left"
st_time_buffer = 15; end_time_buffer = 15
loc_bm = [-46, -41.5, 144.5, 149]
'''
print "  "
# Out:
# /home/eunmia/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))

# %%
from pyhdf.SD import SD

Sync_sec = GetSyncSec(AC_st_time, MODIS_Time) ### 1. Synchronized time between aircraft ad MODIS

Target_st_sec, Target_end_sec = GetTargetSecs(FDate, Sync_sec, st_time_buffer, end_time_buffer)  ### 2.Get target sec in AC

df, df_clouds, df4 = Get_dfNdf_clouds(FDate, Target_st_sec, Target_end_sec, query1, slope, ncname_S) ### 3.Get AC df, df4(Avg)
  ### df: aligned, df_clouds: whole flight in clouds

RR = Rain_Rate(df_clouds)                                                                            ### 4.Cal RR
### 4-1.Get Drizzle df
df_D, df_clouds_D, df4_D = Get_dfNdf_clouds(FDate, Target_st_sec, Target_end_sec, queryD, slope, ncname_S)  
    
df_MODIS_16, df_MODIS_21, df_MODIS_37,\
                df_MODIS_16_PCL, df_MODIS_21_PCL, df_MODIS_37_PCL = Get_MODISReff(FDate, df, km)  ### 5. Cal MODIS df
# Out:
# -c:12: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
# -c:31: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
# /home/eunmia/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/generic.py:1858: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
#   self[name] = value
# Sync_sec :  2582
# 20130614_133658 Target_st_sec:  2582
# len(df):
#  1800 , len(df_clouds):  382
# len(df):
#  1800 , len(df_clouds):  0
# -43.9340555217
#  -43.28544212 147.930269013 148.66641782
# len(16):  921  len(16_PCL):  346
# len(21):  2010  len(21_PCL):  1147
# len(37):  2008  len(37_PCL):  1154

# %%
df_MODIS_21
# Out:
#         Unnamed: 0  CER_UC_16  CER_UC_21  CER_UC_37  CMLF  COT_16  COT_16_PCL  \
# 540760         514      -9999        439        570     1  -99.99      -99.99
# 542114         514      -9999        468        561     1  -99.99      -99.99
# 542115         515      -9999        459        574     1  -99.99      -99.99
# 542116         516      -9999        433        594     1  -99.99      -99.99
# 542117         517      -9999        448        610     1  -99.99      -99.99
# 542118         518      -9999        504        570     1  -99.99      -99.99
# 543467         513      -9999        454        599     1  -99.99      -99.99
# 543468         514      -9999        459        561     1  -99.99      -99.99
# 543469         515      -9999        410        578     1  -99.99      -99.99
# 543470         516      -9999        461        564     1  -99.99      -99.99
# 543471         517      -9999        464        606     1  -99.99      -99.99
# 543472         518      -9999        496        554     1  -99.99      -99.99
# 543473         519      -9999        543        654     1  -99.99      -99.99
# 543474         520      -9999        536        563     1  -99.99      -99.99
# 544821         513      -9999        411        576     1  -99.99      -99.99
# 544822         514      -9999        429        581     1  -99.99      -99.99
# 544823         515        617        471        576     1   35.91      -99.99
# 544824         516        655        441        591     1   29.66      -99.99
# 544825         517        658        459        560     1   24.34      -99.99
# 544826         518       1222        546        603     1   12.72      -99.99
# 544827         519       1054        527        568     1   13.23      -99.99
# 544828         520       1908        576        638     1    8.79      -99.99
# 544832         524        965        536        588     1   13.04      -99.99
# 544833         525        877        501        594     1   12.64      -99.99
# 544834         526       1811        719       1517     1    3.31      -99.99
# 546175         513      -9999        437        552     1  -99.99      -99.99
# 546176         514      -9999        470        649     1  -99.99      -99.99
# 546177         515      -9999        439        536     1  -99.99      -99.99
# 546178         516      -9999        430        603     1  -99.99      -99.99
# 546179         517      -9999        459        556     1  -99.99      -99.99
# 546180         518      -9999        747        802     1  -99.99      -99.99
# 546181         519      -9999        688        826     1  -99.99      -99.99
# 546186         524      -9999        563        535     1  -99.99      -99.99
# 546187         525      -9999        630        567     1  -99.99      -99.99
# 546188         526      -9999       1017       1721     1  -99.99      -99.99
# 547528         512        953        490        530     1    9.06      -99.99
# 547529         513       1545        502        563     1   11.08      -99.99
# 547530         514        978        443        544     1    9.45      -99.99
# 547531         515      -9999        403        577     1  -99.99      -99.99
# 547532         516        639        397        554     1   21.74      -99.99
# 547533         517        623        449        560     1   33.39      -99.99
# 547534         518      -9999        452        655     1  -99.99      -99.99
# 547535         519      -9999        574        646     2  -99.99      -99.99
# 547540         524      -9999        454        570     1  -99.99      -99.99
# 547541         525      -9999        485        582     1  -99.99      -99.99
# 547542         526      -9999        603        664     1  -99.99      -99.99
# 547547         531       1747        836       1006     1    4.03      -99.99
# 548883         513       1414        599        871     1    5.04      -99.99
# 548884         514        826        430        574     1   16.93      -99.99
# 548885         515        639        394        592     1   27.87      -99.99
# 548886         516        783        462        565     1   94.84      -99.99
# 548887         517        955        534        603     1   34.71      -99.99
# 548888         518       1583        571        603     1    6.49      -99.99
# 548894         524        967        481        625     1   14.91      -99.99
# 548895         525        882        482        645     1   26.08      -99.99
# 548896         526        926        517        651     1   15.99      -99.99
# 548906         536       2034       1051        959     1    3.85      -99.99
# 548907         537       2144        945        995     1    3.64      -99.99
# 550237         513      -9999        517        643     1  -99.99      -99.99
# 550238         514      -9999        462        598     1  -99.99      -99.99
# 550239         515      -9999        440        600     1  -99.99      -99.99
# 550240         516      -9999        459        561     1  -99.99      -99.99
# 550241         517      -9999        431        604     1  -99.99      -99.99
# 550242         518      -9999        485        564     1  -99.99      -99.99
# 550248         524      -9999        682        639     1  -99.99      -99.99
# 550249         525      -9999        607        670     1  -99.99      -99.99
# 550250         526      -9999        597        582     1  -99.99      -99.99
# 550251         527      -9999        890       1752     1  -99.99      -99.99
# 550260         536      -9999       1343       4148     1  -99.99      -99.99
# 550261         537      -9999       1081       2777     1  -99.99      -99.99
# 550265         541      -9999        905        976     1  -99.99      -99.99
# 551591         513      -9999        648        987     1  -99.99      -99.99
# 551592         514       1078        535        626     1   20.28      -99.99
# 551593         515       1031        509        605     1   51.47      -99.99
# 551594         516        982        508        617     1  106.07      -99.99
# 551595         517       1004        492        649     1   22.53      -99.99
# 551596         518       1410        535        604     1    9.54      -99.99
# 551602         524       2298       1052       1068     1    3.40      -99.99
# 551603         525       1748        740        584     1    8.50      -99.99
# 551604         526       1963        855        617     2    6.05      -99.99
# 551605         527      -9999        517        745     1  -99.99      -99.99
# 551606         528      -9999        407        591     1  -99.99      -99.99
# 551614         536       1946       1037       3043     1    2.13      -99.99
# 551615         537       1864        806       1326     1    3.53      -99.99
# 551620         542       3039       1308       6326     1    1.19      -99.99
# 551621         543       2923       1216       2401     1    1.73      -99.99
# 551622         544      -9999       1024       3254     1  -99.99      -99.99
# 551623         545      -9999        541        915     1  -99.99      -99.99
# 551624         546       1335        566        587     1    8.19      -99.99
# 552946         514       1092        571        679     1    8.23      -99.99
# 552947         515      -9999        474        641     1  -99.99      -99.99
# 552948         516       1079        522        628     1   16.36      -99.99
# 552949         517      -9999        479        596     1  -99.99      -99.99
# 552950         518      -9999        497        589     1  -99.99      -99.99
# 552951         519        688        462        607     1   28.92      -99.99
# 552957         525      -9999        905        738     1  -99.99      -99.99
# 552958         526       1246        722        633     1    7.09      -99.99
# 552959         527        921        516        620     1   14.53      -99.99
# 552960         528        824        519        597     1   35.18      -99.99
# 552969         537       2410        952       2360     1    2.38      -99.99
# 552970         538      -9999        670        729     1  -99.99      -99.99
# 552976         544      -9999        596       1241     1  -99.99      -99.99
# 552977         545      -9999        519        697     1  -99.99      -99.99
# 552978         546       1905        649        571     1    6.67      -99.99
# 552979         547       2286        891       1900     1    1.87      -99.99
# 552980         548       1960        611       1132     1    3.88      -99.99
# 552981         549        945        495        588     1   10.77      -99.99
# 552982         550       1221        537        624     1    8.17      -99.99
# 554300         514       2266        713        853     1    3.59      -99.99
# 554301         515       1766        596        568     1    9.68      -99.99
# 554302         516       1294        515        635     1   13.81      -99.99
# 554303         517       1873        596        576     1   10.40      -99.99
# 554304         518       1113        487        612     1    7.32      -99.99
# 554305         519      -9999        478        580     1  -99.99      -99.99
# 554311         525      -9999        853      -9999     1  -99.99      -99.99
# 554312         526       2297        993       1365     1    2.93      -99.99
# 554313         527       1821        667        621     1    7.52      -99.99
# 554314         528       1436        561        612     1   12.86      -99.99
# 554315         529       1609        622        566     1   10.07      -99.99
# 554316         530       1740        593        567     1    8.37      -99.99
# 554323         537       2269       1155       3147     1    1.94      -99.99
# 554324         538       1354        669        680     1    6.79      -99.99
# 554330         544       1735        734        884     1    4.47      -99.99
# 554331         545       1908        644        657     1    6.54      -99.99
# 554332         546       2119        746        903     1    3.99      -99.99
# 554334         548      -9999        455        589     1  -99.99      -99.99
# 554335         549       1513        626        589     1    7.99      -99.99
# 554336         550       1193        572        624     1   13.15      -99.99
# 554337         551      -9999        563        575     1  -99.99      -99.99
# 555657         517      -9999        624        723     1  -99.99      -99.99
# 555658         518      -9999        601        596     1  -99.99      -99.99
# 555659         519      -9999        528        601     1  -99.99      -99.99
# 555660         520      -9999        441        568     1  -99.99      -99.99
# 555665         525      -9999        488        676     1  -99.99      -99.99
# 555666         526      -9999        964       1568     1  -99.99      -99.99
# 555667         527      -9999        983        856     1  -99.99      -99.99
# 555668         528      -9999        597        614     1  -99.99      -99.99
# 555669         529      -9999        518        595     1  -99.99      -99.99
# 555670         530      -9999        550        690     1  -99.99      -99.99
# 555671         531      -9999        580        626     1  -99.99      -99.99
# 555672         532      -9999        569        637     1  -99.99      -99.99
# 555673         533      -9999        923       2200     1  -99.99      -99.99
# 555677         537      -9999       1268      -9999     1  -99.99      -99.99
# 555678         538      -9999        914        938     1  -99.99      -99.99
# 555679         539      -9999        679        705     2  -99.99      -99.99
# 555684         544      -9999        764       1000     1  -99.99      -99.99
# 555685         545      -9999        671        620     1  -99.99      -99.99
# 555686         546      -9999        832       1806     1  -99.99      -99.99
# 555687         547      -9999        577      -9999     1  -99.99      -99.99
# 555688         548      -9999        598        546     1  -99.99      -99.99
# 555689         549      -9999        626        716     1  -99.99      -99.99
# 555690         550      -9999        889       1978     1  -99.99      -99.99
# 555691         551      -9999       1130       2556     1  -99.99      -99.99
# 557011         517      -9999        678        684     1  -99.99      -99.99
# 557012         518      -9999        722        595     2  -99.99      -99.99
# 557013         519      -9999        679        812     1  -99.99      -99.99
# 557014         520      -9999        506        637     1  -99.99      -99.99
# 557020         526      -9999        752       1292     1  -99.99      -99.99
# 557021         527      -9999        809       2175     1  -99.99      -99.99
# 557022         528      -9999        625        602     1  -99.99      -99.99
# 557023         529      -9999        599        630     1  -99.99      -99.99
# 557024         530      -9999        574        617     1  -99.99      -99.99
# 557025         531      -9999        573        566     1  -99.99      -99.99
# 557026         532      -9999        605        563     1  -99.99      -99.99
# 557027         533      -9999        608        739     1  -99.99      -99.99
# 557028         534      -9999        573        647     1  -99.99      -99.99
# 557029         535      -9999        592        656     1  -99.99      -99.99
# 557030         536      -9999        602       1357     1  -99.99      -99.99
# 557031         537      -9999        657        631     1  -99.99      -99.99
# 557032         538      -9999        651       1054     1  -99.99      -99.99
# 557033         539      -9999        636        576     1  -99.99      -99.99
# 557037         543      -9999        733       1745     1  -99.99      -99.99
# 557038         544      -9999        623        701     1  -99.99      -99.99
# 557039         545      -9999        726        722     1  -99.99      -99.99
# 557040         546      -9999       1058       2083     1  -99.99      -99.99
# 557041         547      -9999        706       1595     1  -99.99      -99.99
# 557042         548      -9999        477        651     1  -99.99      -99.99
# 557043         549      -9999        411        602     1  -99.99      -99.99
# 557053         559      -9999        474        657     1  -99.99      -99.99
# 558367         519       2216        681        654     2    6.49      -99.99
# 558368         520       1491        528        555     1    9.79      -99.99
# 558369         521       1508        506        578     1   16.40      -99.99
# 558374         526       2193        886        835     1    3.99      -99.99
# 558375         527      -9999       1089       1902     1  -99.99      -99.99
# 558376         528       1967        820        716     1    3.52      -99.99
# 558377         529       1919        628        614     1    7.68      -99.99
# 558378         530        818        540        682     1   13.26      -99.99
# 558379         531       1256        581        621     1    7.93      -99.99
# 558380         532       2007        683        621     1    5.51      -99.99
# 558381         533       1654        777        716     1    5.92      -99.99
# 558382         534       2033        816        646     1    5.84      -99.99
# 558383         535       1252        548        690     1    5.61      -99.99
# 558384         536       2218        816        988     1    3.66      -99.99
# 558385         537      -9999        776        642     1  -99.99      -99.99
# 558386         538       1549        719        584     1    6.84      -99.99
# 558387         539       1973        747        657     1    4.76      -99.99
# 558391         543      -9999        621        913     1  -99.99      -99.99
# 558392         544      -9999        485        628     1  -99.99      -99.99
# 558393         545      -9999        584        617     1  -99.99      -99.99
# 558394         546      -9999        766       3502     1  -99.99      -99.99
# 558395         547      -9999        492        959     1  -99.99      -99.99
# 558396         548        852        462        618     1   15.06      -99.99
# 558397         549       1559        469        674     1   15.29      -99.99
# 558398         550       1499        544        638     1   12.20      -99.99
# 558407         559      -9999       1443       3577     1  -99.99      -99.99
# 559722         520      -9999        552       1009     1  -99.99      -99.99
# 559723         521      -9999        437        591     1  -99.99      -99.99
# 559728         526      -9999        618        721     1  -99.99      -99.99
# 559729         527      -9999       1452      -9999     1  -99.99      -99.99
# 559730         528      -9999        822       1160     1  -99.99      -99.99
# 559731         529      -9999        747        720     1  -99.99      -99.99
# 559732         530      -9999        668        652     1  -99.99      -99.99
# 559733         531      -9999        579        574     1  -99.99      -99.99
# 559734         532      -9999        609        622     1  -99.99      -99.99
# 559735         533      -9999        808        843     1  -99.99      -99.99
# 559736         534      -9999        842       1072     1  -99.99      -99.99
# 559740         538      -9999       1177       2800     1  -99.99      -99.99
# 559741         539      -9999        796        896     1  -99.99      -99.99
# 559745         543      -9999        749       1450     1  -99.99      -99.99
# 559746         544      -9999        653        613     1  -99.99      -99.99
# 559747         545      -9999        801        831     1  -99.99      -99.99
# 559748         546      -9999        715       1839     1  -99.99      -99.99
# 559749         547      -9999        559        626     1  -99.99      -99.99
# 559750         548      -9999        479        585     1  -99.99      -99.99
# 559751         549      -9999        469        603     1  -99.99      -99.99
# 559752         550      -9999        519        577     1  -99.99      -99.99
# 559761         559      -9999       1036      -9999     1  -99.99      -99.99
# 561076         520       2124        585        591     1    8.22      -99.99
# 561077         521       1034        559        604     1   52.06      -99.99
# 561086         530       1077        493        645     1   10.69      -99.99
# 561087         531      -9999        439        567     1  -99.99      -99.99
# 561088         532      -9999        486        622     2  -99.99      -99.99
# 561089         533       2175        936       1540     1    2.88      -99.99
# 561090         534       1763        678        727     1    5.07      -99.99
# 561094         538       2229        755        815     2    4.42      -99.99
# 561095         539       2831        922       2497     1    1.78      -99.99
# 561103         547      -9999        574        559     1  -99.99      -99.99
# 561104         548      -9999        477        558     1  -99.99      -99.99
# 561105         549       1015        451        590     1    8.55      -99.99
# 562430         520      -9999        418        598     1  -99.99      -99.99
# 562431         521        718        423        576     1   24.24      -99.99
# 562440         530       1648        689        586     1    7.79      -99.99
# 562441         531       1283        597        633     1   20.52      -99.99
# 562442         532       1407        563        625     1   13.62      -99.99
# 562443         533       1568        724       1557     1    3.36      -99.99
# 562444         534        872        466        640     1   10.86      -99.99
# 562449         539       1717        710        855     1    4.63      -99.99
# 562457         547       1470        624        747     1    5.31      -99.99
# 562458         548        967        456        605     1    9.44      -99.99
# 562459         549        768        430        587     1   13.14      -99.99
# 562460         550        688        428        625     1   29.65      -99.99
# 562461         551        840        495        675     1   31.11      -99.99
# 563785         521      -9999        465        552     1  -99.99      -99.99
# 563794         530      -9999        660        594     1  -99.99      -99.99
# 563795         531      -9999        595        635     1  -99.99      -99.99
# 563796         532      -9999        545        611     1  -99.99      -99.99
# 563797         533      -9999        676        954     1  -99.99      -99.99
# 563798         534      -9999        712        607     1  -99.99      -99.99
# 563803         539      -9999        558        576     1  -99.99      -99.99
# 563811         547      -9999        979       2669     1  -99.99      -99.99
# 563812         548      -9999        484        579     1  -99.99      -99.99
# 563813         549      -9999        487        650     1  -99.99      -99.99
# 563814         550      -9999        486        609     1  -99.99      -99.99
# 563815         551      -9999        466        624     1  -99.99      -99.99
# 565138         520        747        470        581     1   63.04      -99.99
# 565139         521        938        480        593     1   26.84      -99.99
# 565140         522       1203        562        704     1   15.25      -99.99
# 565149         531       1571        619        556     1    7.58      -99.99
# 565150         532       1311        582        576     1    9.56      -99.99
# 565151         533       1500        694        693     1    6.36      -99.99
# 565152         534      -9999        477        583     1  -99.99      -99.99
# 565161         543      -9999       1150      -9999     1  -99.99      -99.99
# 565162         544      -9999       1024      -9999     1  -99.99      -99.99
# 565163         545       1588        764       1027     1    4.17      -99.99
# 565164         546       1543        721       1151     1    4.00      -99.99
# 565165         547      -9999        770      -9999     1  -99.99      -99.99
# 565166         548        921        479        595     1   10.43      -99.99
# 565167         549        904        424        617     1   13.13      -99.99
# 565168         550        846        442        611     1   12.39      -99.99
# 565169         551      -9999        419        656     1  -99.99      -99.99
# 566491         519        782        480        570     1  150.00      -99.99
# 566492         520        965        514        591     1  150.00      -99.99
# 566493         521       1458        484        651     1   19.36      -99.99
# 566494         522        902        511        654     1   15.23      -99.99
# 566495         523       1232        712        631     2    7.54      -99.99
# 566504         532        802        543        597     2   12.26      -99.99
# 566505         533       2483        765        794     1    4.04      -99.99
# 566506         534       1789        598        588     1    9.75      -99.99
# 566510         538       1901        642        637     1    6.69      -99.99
# 566516         544      -9999        585       1124     1  -99.99      -99.99
# 566517         545      -9999        695       2289     1  -99.99      -99.99
# 566518         546      -9999        737       1695     1  -99.99      -99.99
# 566519         547      -9999        555        944     1  -99.99      -99.99
# 566520         548       2236        596        595     1    6.17      -99.99
# 566521         549      -9999        413        623     1  -99.99      -99.99
# 566522         550      -9999        372        663     1  -99.99      -99.99
# 566523         551        742        413        641     1   16.53      -99.99
# 566527         555      -9999        748        921     1  -99.99      -99.99
# 567845         519      -9999        578        682     1  -99.99      -99.99
# 567846         520       1030        625        599     1  150.00      -99.99
# 567847         521       1001        545        606     1   66.66      -99.99
# 567848         522       3522        718        598     1    6.99      -99.99
# 567858         532       1451        549        582     1   10.71      -99.99
# 567859         533       1967        683       1812     1    3.10      -99.99
# 567860         534      -9999       1058       1057     1  -99.99      -99.99
# 567861         535       1414        752        615     2    6.37      -99.99
# 567862         536      -9999        585       1040     1  -99.99      -99.99
# 567863         537       1913        847        829     1    3.38      -99.99
# 567864         538      -9999        915        690     1  -99.99      -99.99
# 567870         544       1358        574        666     1   10.23      -99.99
# 567871         545       1819        679        629     1    6.30      -99.99
# 567872         546      -9999        579        918     1  -99.99      -99.99
# 567873         547       1090        556        566     1    7.51      -99.99
# 567874         548       2102        693       1447     1    2.68      -99.99
# 567875         549        913        460        660     1   17.57      -99.99
# 567876         550        997        460        591     1   43.71      -99.99
# 567877         551       1005        496        620     1   41.37      -99.99
# 567881         555       2942       1071      -9999     1    1.41      -99.99
# 569199         519      -9999        498        584     1  -99.99      -99.99
# 569200         520      -9999        594        508     2  -99.99      -99.99
# 569201         521      -9999        768        566     1  -99.99      -99.99
# 569202         522      -9999        499        651     1  -99.99      -99.99
# 569206         526      -9999        701        697     1  -99.99      -99.99
# 569212         532      -9999        473        589     1  -99.99      -99.99
# 569213         533      -9999        475        688     1  -99.99      -99.99
# 569214         534      -9999        542       1107     1  -99.99      -99.99
# 569215         535      -9999        951       2191     1  -99.99      -99.99
# 569216         536      -9999        840        748     1  -99.99      -99.99
# 569217         537      -9999        674       1679     1  -99.99      -99.99
# 569218         538      -9999        786        840     1  -99.99      -99.99
# 569219         539      -9999        749        580     1  -99.99      -99.99
# 569220         540      -9999        648        622     1  -99.99      -99.99
# 569224         544      -9999       1060       3559     1  -99.99      -99.99
# 569225         545      -9999        578        903     1  -99.99      -99.99
# 569226         546      -9999        487        565     1  -99.99      -99.99
# 569227         547      -9999        630        733     1  -99.99      -99.99
# 569229         549      -9999        447        624     1  -99.99      -99.99
# 569230         550      -9999        435        619     1  -99.99      -99.99
# 569231         551      -9999        440        650     1  -99.99      -99.99
# 569236         556      -9999        433        621     1  -99.99      -99.99
# 570547         513      -9999        856       2356     1  -99.99      -99.99
# 570553         519      -9999        447        545     1  -99.99      -99.99
# 570561         527      -9999        775        575     1  -99.99      -99.99
# 570565         531      -9999        851       2691     1  -99.99      -99.99
# 570566         532      -9999        598        658     1  -99.99      -99.99
# 570567         533      -9999        526        645     1  -99.99      -99.99
# 570568         534      -9999        562        657     1  -99.99      -99.99
# 570569         535      -9999        665        658     2  -99.99      -99.99
# 570570         536      -9999        538       1465     1  -99.99      -99.99
# 570571         537      -9999        588        595     1  -99.99      -99.99
# 570572         538      -9999        542        669     2  -99.99      -99.99
# 570573         539      -9999        734        937     1  -99.99      -99.99
# 570579         545      -9999        619        892     1  -99.99      -99.99
# 570580         546      -9999        762        766     1  -99.99      -99.99
# 570581         547      -9999        645       1411     1  -99.99      -99.99
# 570582         548      -9999        430        611     1  -99.99      -99.99
# 570583         549      -9999        438        653     1  -99.99      -99.99
# 570584         550      -9999        429        620     1  -99.99      -99.99
# 570585         551      -9999        424        639     1  -99.99      -99.99
# 570586         552      -9999        423        615     1  -99.99      -99.99
# 570587         553      -9999        458        711     1  -99.99      -99.99
# 570588         554      -9999        563       1428     1  -99.99      -99.99
# 570589         555      -9999        555        652     1  -99.99      -99.99
# 570590         556      -9999        550        664     1  -99.99      -99.99
# 571896         508       1174        488        578     1   20.29      -99.99
# 571907         519        693        456        568     1   33.42      -99.99
# 571916         528        914        518        619     1   11.60      -99.99
# 571917         529      -9999        503        601     1  -99.99      -99.99
# 571918         530       1114        599        689     1    9.32      -99.99
# 571919         531      -9999        507        566     1  -99.99      -99.99
# 571920         532       1385        505        798     1    5.02      -99.99
# 571921         533       1655        577        587     1    9.73      -99.99
# 571922         534      -9999        784        554     2  -99.99      -99.99
# 571923         535       2130        954       1142     1    2.55      -99.99
# 571924         536      -9999        915        749     1  -99.99      -99.99
# 571925         537      -9999       1124       1445     1  -99.99      -99.99
# 571926         538      -9999       1101       1270     1  -99.99      -99.99
# 571927         539      -9999       1279       4332     1  -99.99      -99.99
# 571933         545       1581        514        604     1    7.26      -99.99
# 571934         546      -9999        526        760     1  -99.99      -99.99
# 571935         547       2635        701       1436     1    2.77      -99.99
# 571936         548       1816        496        561     1    7.71      -99.99
# 571937         549       1346        470        575     1   10.39      -99.99
# 571938         550        806        445        656     1   13.40      -99.99
# 571939         551       1075        505        607     1   16.42      -99.99
# 571940         552       1243        515        715     1   24.12      -99.99
# 571941         553       1589        519        625     1   10.23      -99.99
# 571942         554      -9999        534        702     1  -99.99      -99.99
# 571943         555      -9999        501        640     1  -99.99      -99.99
# 571944         556       1744        648        693     1    5.64      -99.99
# 573261         519      -9999        548        626     1  -99.99      -99.99
# 573270         528      -9999        602        579     1  -99.99      -99.99
# 573271         529      -9999        577        537     1  -99.99      -99.99
# 573272         530      -9999        729        596     1  -99.99      -99.99
# 573273         531      -9999        712        634     1  -99.99      -99.99
# 573274         532      -9999        599        567     1  -99.99      -99.99
# 573275         533      -9999        546        542     1  -99.99      -99.99
# 573276         534      -9999        830        700     1  -99.99      -99.99
# 573277         535      -9999       1036       1810     1  -99.99      -99.99
# 573278         536      -9999       1788      -9999     1  -99.99      -99.99
# 573279         537      -9999        986      -9999     1  -99.99      -99.99
# 573280         538      -9999        763       1230     1  -99.99      -99.99
# 573281         539      -9999        915       4075     1  -99.99      -99.99
# 573287         545      -9999        564        631     1  -99.99      -99.99
# 573288         546      -9999        586        560     1  -99.99      -99.99
# 573289         547      -9999        575        904     1  -99.99      -99.99
# 573290         548      -9999        526        601     1  -99.99      -99.99
# 573291         549      -9999        477        646     1  -99.99      -99.99
# 573292         550      -9999        570        640     1  -99.99      -99.99
# 573293         551      -9999       1200      -9999     1  -99.99      -99.99
# 573294         552      -9999        639        694     1  -99.99      -99.99
# 573295         553      -9999        593       1194     1  -99.99      -99.99
# 573296         554      -9999       1209      -9999     1  -99.99      -99.99
# 573297         555      -9999        701       1003     1  -99.99      -99.99
# 574615         519       1256        546        621     1   28.97      -99.99
# 574626         530       1571        591        606     1   14.59      -99.99
# 574627         531       2186        843        557     2    6.18      -99.99
# 574628         532       1898        652        629     1    6.77      -99.99
# 574629         533       1568        580        647     2    7.37      -99.99
# 574630         534      -9999        776       1305     1  -99.99      -99.99
# 574631         535      -9999        927       2712     1  -99.99      -99.99
# 574632         536      -9999        504       1140     1  -99.99      -99.99
# 574633         537       1172        509        612     1   12.09      -99.99
# 574634         538       1316        543        681     1    6.60      -99.99
# 574635         539      -9999        591       1707     1  -99.99      -99.99
# 574636         540      -9999        513        586     1  -99.99      -99.99
# 574637         541      -9999        507        558     1  -99.99      -99.99
# 574641         545       1993        679        597     1    5.02      -99.99
# 574642         546       2641        670        855     1    3.80      -99.99
# 574643         547       1521        581        891     1    4.83      -99.99
# 574647         551       2395        709        641     1    4.78      -99.99
# 574648         552      -9999        934      -9999     1  -99.99      -99.99
# 574651         555      -9999        616        803     1  -99.99      -99.99
# 575968         518       1443        707        833     1    4.86      -99.99
# 575969         519       1962        870        492     2    5.66      -99.99
# 575980         530       1393        689        546     2   11.26      -99.99
# 575981         531       2319        907       1314     1    2.89      -99.99
# 575982         532       1480        660        574     1    8.41      -99.99
# 575983         533       1086        556        580     1   23.59      -99.99
# 575984         534       2141        825       1179     1    3.17      -99.99
# 575985         535      -9999        644       1797     1  -99.99      -99.99
# 575986         536       1543        658        631     1    6.80      -99.99
# 575987         537       1858        685        628     2    6.95      -99.99
# 575988         538       1014        513        544     1    7.93      -99.99
# 575989         539      -9999        429        603     2  -99.99      -99.99
# 575990         540       2098        785       1214     1    3.58      -99.99
# 575991         541       1665        655        702     1    5.73      -99.99
# 575992         542       1142        572        592     1   10.81      -99.99
# 575993         543       1832        721        841     1    4.54      -99.99
# 575994         544       2853       1137       3533     1    1.56      -99.99
# 575995         545       2168        948       1567     1    2.96      -99.99
# 575997         547       1212        525        569     1    7.47      -99.99
# 577327         523      -9999        451        637     1  -99.99      -99.99
# 577328         524      -9999        481        673     1  -99.99      -99.99
# 577334         530      -9999        748        589     2  -99.99      -99.99
# 577335         531      -9999       1112       3614     1  -99.99      -99.99
# 577336         532      -9999        856        854     1  -99.99      -99.99
# 577337         533      -9999        881        626     2  -99.99      -99.99
# 577338         534      -9999       1072       3942     1  -99.99      -99.99
# 577339         535      -9999        753        741     1  -99.99      -99.99
# 577340         536      -9999        829        765     2  -99.99      -99.99
# 577341         537      -9999       1249       3005     1  -99.99      -99.99
# 577342         538      -9999        613        647     1  -99.99      -99.99
# 577343         539      -9999        588        639     1  -99.99      -99.99
# 577345         541      -9999        423        607     1  -99.99      -99.99
# 577350         546      -9999        428        626     1  -99.99      -99.99
# 577351         547      -9999        443        602     1  -99.99      -99.99
# 577355         551      -9999        403        648     1  -99.99      -99.99
# 577356         552      -9999        413        644     1  -99.99      -99.99
# 578681         523       1103        538        671     1   18.19      -99.99
# 578682         524       1184        601        577     1   29.95      -99.99
# 578690         532       1442        709        620     1    6.00      -99.99
# 578691         533       1632        725        588     2    6.65      -99.99
# 578692         534       2344       1059       3362     1    1.77      -99.99
# 578693         535       2577       1009        950     1    3.46      -99.99
# 578694         536       2486       1061       1677     1    2.29      -99.99
# 578695         537      -9999        546        853     1  -99.99      -99.99
# 578696         538       1052        513        647     1   15.02      -99.99
# 578697         539       1238        519        586     1   10.78      -99.99
# 578698         540        753        422        602     1   15.82      -99.99
# 578699         541        860        442        637     1   20.58      -99.99
# 578704         546      -9999        485        563     1  -99.99      -99.99
# 578705         547      -9999        432        623     1  -99.99      -99.99
# 578706         548      -9999        401        569     1  -99.99      -99.99
# 578707         549        948        461        574     1   11.98      -99.99
# 578708         550        967        444        620     1   17.85      -99.99
# 578709         551       1052        486        638     1   25.34      -99.99
# 578710         552       1004        449        624     1   16.66      -99.99
# 578717         559      -9999        599       1190     1  -99.99      -99.99
# 580027         515      -9999        394        585     1  -99.99      -99.99
# 580035         523        991        553        597     1   23.86      -99.99
# 580036         524       3429        907        858     1    2.80      -99.99
# 580048         536      -9999        535        762     1  -99.99      -99.99
# 580049         537       1003        632        594     1   10.69      -99.99
# 580050         538       1180        636        645     1    8.12      -99.99
# 580051         539      -9999        446        641     1  -99.99      -99.99
# 580052         540        646        423        616     1   25.42      -99.99
# 580053         541        718        479        591     1   40.28      -99.99
# 580058         546       1750        475        633     1   11.76      -99.99
# 580059         547       1708        497        589     1   11.25      -99.99
# 580060         548       1206        466        626     1   12.97      -99.99
# 580061         549       1823        448        573     1    7.47      -99.99
# 580062         550      -9999        418        643     1  -99.99      -99.99
# 580063         551        726        426        623     1   14.69      -99.99
# 580065         553      -9999        530        542     1  -99.99      -99.99
# 580066         554      -9999        568        623     1  -99.99      -99.99
# 580074         562      -9999        504        657     1  -99.99      -99.99
# 581378         512      -9999        732       1633     1  -99.99      -99.99
# 581380         514      -9999        436        595     1  -99.99      -99.99
# 581381         515        834        480        657     1   61.14      -99.99
# 581382         516        656        508        606     1   20.68      -99.99
# 581389         523       2015       1076       1164     1    2.37      -99.99
# 581390         524      -9999        742        915     1  -99.99      -99.99
# 581402         536       2071        710        635     1    4.29      -99.99
# 581403         537      -9999        589        679     1  -99.99      -99.99
# 581404         538       1754        522        592     1    6.73      -99.99
# 581405         539       1519        449        586     1   11.48      -99.99
# 581406         540       1075        466        615     1   24.71      -99.99
# 581407         541       1018        472        591     1   26.62      -99.99
# 581412         546       1020        525        638     1   11.80      -99.99
# 581413         547        697        480        627     1   16.21      -99.99
# 581414         548      -9999        533        588     1  -99.99      -99.99
# 581415         549      -9999        400        655     1  -99.99      -99.99
# 581416         550       1028        463        609     1   26.42      -99.99
# 581417         551       1472        503        603     1   12.39      -99.99
# 581418         552        781        442        636     1   24.79      -99.99
# 581419         553       1078        458        613     1   16.12      -99.99
# 581420         554        820        506        724     1   13.13      -99.99
# 582732         512      -9999        578       1022     2  -99.99      -99.99
# 582733         513      -9999        522        755     1  -99.99      -99.99
# 582734         514      -9999        518        613     1  -99.99      -99.99
# 582735         515      -9999        556        591     1  -99.99      -99.99
# 582736         516      -9999        634        561     1  -99.99      -99.99
# 582745         525      -9999        947        740     1  -99.99      -99.99
# 582756         536      -9999        953       1160     1  -99.99      -99.99
# 582757         537      -9999        678        620     1  -99.99      -99.99
# 582758         538      -9999        442        624     1  -99.99      -99.99
# 582759         539      -9999        468        592     1  -99.99      -99.99
# 582760         540      -9999        482        621     1  -99.99      -99.99
# 582761         541      -9999        406        603     1  -99.99      -99.99
# 582762         542      -9999        442        599     1  -99.99      -99.99
# 582763         543      -9999        521        565     1  -99.99      -99.99
# 582765         545      -9999        595        882     1  -99.99      -99.99
# 582766         546      -9999        550        635     1  -99.99      -99.99
# 582767         547      -9999        835        974     1  -99.99      -99.99
# 582768         548      -9999        628       1302     1  -99.99      -99.99
# 582769         549      -9999        456        578     1  -99.99      -99.99
# 582770         550      -9999        398        652     1  -99.99      -99.99
# 582771         551      -9999        433        603     1  -99.99      -99.99
# 582772         552      -9999        533        715     1  -99.99      -99.99
# 582773         553      -9999        581        618     1  -99.99      -99.99
# 584084         510      -9999        705       1447     1  -99.99      -99.99
# 584085         511      -9999        784       1200     1  -99.99      -99.99
# 584086         512      -9999        454        562     1  -99.99      -99.99
# 584087         513      -9999        509        598     1  -99.99      -99.99
# 584088         514      -9999        632        615     1  -99.99      -99.99
# 584089         515      -9999        582        582     1  -99.99      -99.99
# 584090         516      -9999        688        516     2  -99.99      -99.99
# 584099         525      -9999        471        611     1  -99.99      -99.99
# 584110         536      -9999        798        632     1  -99.99      -99.99
# 584111         537      -9999        719        714     1  -99.99      -99.99
# 584112         538      -9999        503        544     1  -99.99      -99.99
# 584113         539      -9999        486        609     1  -99.99      -99.99
# 584114         540      -9999        526        573     1  -99.99      -99.99
# 584115         541      -9999        479        656     1  -99.99      -99.99
# 584116         542      -9999        487        595     1  -99.99      -99.99
# 584117         543      -9999        434        641     1  -99.99      -99.99
# 584118         544      -9999        533        794     1  -99.99      -99.99
# 584119         545      -9999        711        805     1  -99.99      -99.99
# 584120         546      -9999        759       1367     1  -99.99      -99.99
# 584122         548      -9999        430        579     1  -99.99      -99.99
# 584123         549      -9999        412        596     1  -99.99      -99.99
# 584124         550      -9999        461        595     1  -99.99      -99.99
# 584125         551      -9999        514        657     1  -99.99      -99.99
# 584126         552      -9999        737        605     1  -99.99      -99.99
# 584127         553      -9999        537        607     1  -99.99      -99.99
# 585438         510      -9999        610        688     1  -99.99      -99.99
# 585439         511       1272        617        726     1    5.61      -99.99
# 585440         512      -9999        779        694     1  -99.99      -99.99
# 585441         513      -9999        767        636     1  -99.99      -99.99
# 585442         514       2425        709        712     1    4.56      -99.99
# 585443         515       1322        658        602     1    9.47      -99.99
# 585444         516      -9999        668        600     2  -99.99      -99.99
# 585445         517      -9999        974       1847     1  -99.99      -99.99
# 585453         525       1643        651        623     1   12.02      -99.99
# 585454         526       1657        571        584     1   16.18      -99.99
# 585464         536      -9999       1080       1783     1  -99.99      -99.99
# 585465         537      -9999        581        900     1  -99.99      -99.99
# 585466         538      -9999        441        644     1  -99.99      -99.99
# 585467         539       1190        481        601     1   11.77      -99.99
# 585468         540        808        448        591     1   13.46      -99.99
# ...
# 632849    14.68       -99.99    12.34       -99.99
# 632850    27.84       -99.99    21.08       -99.99
# 632851    26.90       -99.99    21.46       -99.99
# 632852    17.05       -99.99    15.12       -99.99
# 632853    12.64       -99.99    11.51       -99.99
# 632854    16.54       -99.99    13.97       -99.99
# 632855    14.23       -99.99    14.07       -99.99
# 632856    15.09       -99.99    14.66       -99.99
# 632857    17.49       -99.99    16.95       -99.99
# 632858    20.42       -99.99    17.77       -99.99
# 632859    21.04       -99.99    19.55       -99.99
# 632860    18.61       -99.99    18.38       -99.99
# 632861    18.32       -99.99    17.28       -99.99
# 632862    19.02       -99.99    18.95       -99.99
# 632863    20.35       -99.99    19.84       -99.99
# 632864    15.83       -99.99    16.52       -99.99
# 632865    18.04       -99.99    17.99       -99.99
# 632866    23.99       -99.99    21.22       -99.99
# 632867    17.50       -99.99    19.00       -99.99
# 632868    26.86       -99.99    23.30       -99.99
# 632869    23.95       -99.99    20.94       -99.99
# 632870    16.48       -99.99    13.52       -99.99
# 634168    14.77       -99.99    15.71       -99.99
# 634169    16.08       -99.99    16.37       -99.99
# 634170    15.75       -99.99    16.54       -99.99
# 634171    12.29       -99.99    14.53       -99.99
# 634172    13.16       -99.99    14.82       -99.99
# 634173    13.59       -99.99    14.70       -99.99
# 634174    15.82       -99.99    15.68       -99.99
# 634175    14.73       -99.99    15.86       -99.99
# 634176    15.59       -99.99    15.91       -99.99
# 634177    16.31       -99.99    16.84       -99.99
# 634178    13.54       -99.99    15.48       -99.99
# 634179    15.05       -99.99    12.86       -99.99
# 634180    13.04       -99.99    13.06       -99.99
# 634181    18.62       -99.99    16.30       -99.99
# 634182    14.91       -99.99    12.98       -99.99
# 634183    12.52       -99.99    12.20       -99.99
# 634199    14.46       -99.99    13.37       -99.99
# 634200    16.49       -99.99    14.73       -99.99
# 634201    12.30       -99.99    12.21       -99.99
# 634202    13.01       -99.99    11.83       -99.99
# 634203    18.37       -99.99    14.66       -99.99
# 634204    15.62       -99.99    14.54       -99.99
# 634205    12.08       -99.99    12.86       -99.99
# 634206    11.63       -99.99    11.55       -99.99
# 634207    11.46       -99.99    10.46       -99.99
# 634208    22.03       -99.99    16.18       -99.99
# 634209    14.71       -99.99    14.67       -99.99
# 634210    15.27       -99.99    14.95       -99.99
# 634211    15.13       -99.99    14.05       -99.99
# 634212    16.58       -99.99    15.06       -99.99
# 634213    15.69       -99.99    16.44       -99.99
# 634214    15.61       -99.99    16.29       -99.99
# 634215    20.94       -99.99    19.51       -99.99
# 634216    20.45       -99.99    18.81       -99.99
# 634217    18.13       -99.99    18.58       -99.99
# 634218    20.18       -99.99    17.07       -99.99
# 634219    25.63       -99.99    22.42       -99.99
# 634220    21.02       -99.99    18.68       -99.99
# 634221    20.14       -99.99    20.22       -99.99
# 634222    17.09       -99.99    18.96       -99.99
# 634223    12.40       -99.99    14.32       -99.99
# 634224    21.59       -99.99    15.30       -99.99
# 635523    14.20       -99.99    15.61       -99.99
# 635524    13.61       -99.99    15.46       -99.99
# 635525    15.27       -99.99    15.82       -99.99
# 635526    14.35       -99.99    15.34       -99.99
# 635527    14.42       -99.99    14.34       -99.99
# 635528    16.31       -99.99    16.03       -99.99
# 635529    14.34       -99.99    15.43       -99.99
# 635530    13.80       -99.99    15.21       -99.99
# 635531    12.50       -99.99    13.91       -99.99
# 635532    13.88       -99.99    14.57       -99.99
# 635533    15.55       -99.99    15.48       -99.99
# 635534    16.03       -99.99    14.43       -99.99
# 635535    14.01       -99.99    14.25       -99.99
# 635536    11.97       -99.99    11.90       -99.99
# 635537    13.00       -99.99    12.55       -99.99
# 635553    13.85       -99.99    12.01       -99.99
# 635554    23.34       -99.99    18.50       -99.99
# 635555    16.76       -99.99    13.21       -99.99
# 635556    14.94       -99.99    13.43       -99.99
# 635557    18.34       -99.99    14.06       -99.99
# 635558    18.88       -99.99    16.74       -99.99
# 635562    19.22       -99.99    16.26       -99.99
# 635563    15.11       -99.99    13.40       -99.99
# 635564    16.17       -99.99    14.45       -99.99
# 635565    17.32       -99.99    16.30       -99.99
# 635566    18.13       -99.99    16.97       -99.99
# 635567    18.00       -99.99    16.95       -99.99
# 635568    20.91       -99.99    19.06       -99.99
# 635569    21.00       -99.99    19.94       -99.99
# 635570    18.22       -99.99    17.56       -99.99
# 635571    16.47       -99.99    17.25       -99.99
# 635572    19.23       -99.99    18.21       -99.99
# 635573    18.56       -99.99    19.18       -99.99
# 635574    24.20       -99.99    19.22       -99.99
# 635575    19.50       -99.99    18.90       -99.99
# 635576    26.59       -99.99    23.04       -99.99
# 635577    21.83       -99.99    20.09       -99.99
# 635578    21.03       -99.99    14.80       -99.99
# 636881    14.68       -99.99    14.96       -99.99
# 636882    15.40       -99.99    15.71       -99.99
# 636883    14.54       -99.99    15.35       -99.99
# 636884    13.43       -99.99    14.67       -99.99
# 636885    14.93       -99.99    15.57       -99.99
# 636886    13.42       -99.99    14.54       -99.99
# 636887    12.29       -99.99    13.43       -99.99
# 636888    15.46       -99.99    14.09       -99.99
# 636889    15.30       -99.99    15.07       -99.99
# 636890    13.85       -99.99    12.47       -99.99
# 636891    12.50       -99.99    12.15       -99.99
# 636907    18.30       -99.99    14.24       -99.99
# 636908    14.48       -99.99    13.18       -99.99
# 636909    18.52       -99.99    13.41       -99.99
# 636910    16.57       -99.99    15.38       -99.99
# 636911    13.13       -99.99    13.55       -99.99
# 636912    15.64       -99.99    13.85       -99.99
# 636916    14.55       -99.99    13.83       -99.99
# 636917    16.14       -99.99    14.40       -99.99
# 636918    19.52       -99.99    16.70       -99.99
# 636919    18.91       -99.99    16.88       -99.99
# 636920    16.44       -99.99    15.87       -99.99
# 636921    15.93       -99.99    15.71       -99.99
# 636922    14.64       -99.99    15.20       -99.99
# 636923    15.98       -99.99    16.76       -99.99
# 636924    17.68       -99.99    17.40       -99.99
# 636925    13.62       -99.99    15.43       -99.99
# 636926    14.55       -99.99    15.43       -99.99
# 636927    17.90       -99.99    18.22       -99.99
# 636928    14.70       -99.99    17.09       -99.99
# 636929    19.53       -99.99    20.64       -99.99
# 636930    22.25       -99.99    22.96       -99.99
# 636931    14.50       -99.99    16.22       -99.99
# 638239    14.14       -99.99    15.69       -99.99
# 638240    13.21       -99.99    14.70       -99.99
# 638241    12.08       -99.99    13.29       -99.99
# 638242    14.15       -99.99    14.17       -99.99
# 638243    11.81       -99.99    11.63       -99.99
# 638244    12.12       -99.99    12.27       -99.99
# 638245    11.34       -99.99    11.06       -99.99
# 638265    12.18       -99.99    13.66       -99.99
# 638266    12.60       -99.99    13.09       -99.99
# 638272    19.66       -99.99    18.80       -99.99
# 638273    17.54       -99.99    16.61       -99.99
# 638274    14.63       -99.99    13.41       -99.99
# 638275    20.20       -99.99    17.79       -99.99
# 638276    18.34       -99.99    15.57       -99.99
# 638277    17.23       -99.99    16.40       -99.99
# 638278    17.31       -99.99    17.13       -99.99
# 638279    15.29       -99.99    15.91       -99.99
# 638280    17.22       -99.99    15.98       -99.99
# 638281    18.07       -99.99    18.11       -99.99
# 638282    20.43       -99.99    20.18       -99.99
# 638283    23.28       -99.99    22.46       -99.99
# 638284    20.82       -99.99    21.30       -99.99
# 638285    23.16       -99.99    21.69       -99.99
# 639598    14.41       -99.99    14.25       -99.99
# 639599    15.41       -99.99    13.94       -99.99
# 639600    19.51       -99.99    14.86       -99.99
# 639619    22.09       -99.99    18.10       -99.99
# 639620    17.42       -99.99    13.76       -99.99
# 639626    24.13       -99.99    21.26       -99.99
# 639627    16.33       -99.99    15.01       -99.99
# 639628    18.32       -99.99    15.14       -99.99
# 639629    15.97       -99.99    15.84       -99.99
# 639630    16.54       -99.99    16.11       -99.99
# 639631    15.44       -99.99    15.22       -99.99
# 639632    17.00       -99.99    15.81       -99.99
# 639633    15.52       -99.99    14.79       -99.99
# 639634    20.18       -99.99    18.18       -99.99
# 639635    17.03       -99.99    17.08       -99.99
# 639636    21.75       -99.99    20.84       -99.99
# 639637    22.41       -99.99    21.89       -99.99
# 639638    23.79       -99.99    23.19       -99.99
# 639639    21.45       -99.99    21.55       -99.99
# 640973    16.70       -99.99    15.46       -99.99
# 640974    12.28       -99.99    13.36       -99.99
# 640980    16.95       -99.99    14.23       -99.99
# 640981    15.11       -99.99    14.37       -99.99
# 640982    16.54       -99.99    14.56       -99.99
# 640983    16.61       -99.99    15.64       -99.99
# 640984    15.09       -99.99    15.39       -99.99
# 640985    15.92       -99.99    15.64       -99.99
# 640986    16.13       -99.99    16.23       -99.99
# 640987    16.45       -99.99    15.12       -99.99
# 640988    19.77       -99.99    17.71       -99.99
# 640989    28.39       -99.99    25.13       -99.99
# 640990    24.64       -99.99    22.89       -99.99
# 640991    21.06       -99.99    20.77       -99.99
# 640992    14.82       -99.99    17.79       -99.99
# 640993    23.63       -99.99    21.19       -99.99
# 642326    13.37       -99.99    12.85       -99.99
# 642333    19.73       -99.99    16.24       -99.99
# 642334    15.36       -99.99    14.21       -99.99
# 642335    14.78       -99.99    13.63       -99.99
# 642336    15.31       -99.99    13.54       -99.99
# 642337    17.41       -99.99    16.66       -99.99
# 642338    16.33       -99.99    15.93       -99.99
# 642339    15.45       -99.99    14.89       -99.99
# 642340    16.23       -99.99    15.25       -99.99
# 642341    21.59       -99.99    23.19       -99.99
# 642342    28.08       -99.99    26.27       -99.99
# 642343    23.75       -99.99    22.21       -99.99
# 642344    24.95       -99.99    22.66       -99.99
# 642345    16.71       -99.99    18.28       -99.99
# 642346    22.05       -99.99    19.19       -99.99
# 643679    18.78       -99.99    15.40       -99.99
# 643680    15.71       -99.99    15.48       -99.99
# 643685    16.13       -99.99    14.22       -99.99
# 643686    14.79       -99.99    14.04       -99.99
# 643687    13.27       -99.99    12.82       -99.99
# 643688    18.73       -99.99    16.06       -99.99
# 643689    21.48       -99.99    19.05       -99.99
# 643690    23.14       -99.99    18.70       -99.99
# 643691    17.75       -99.99    17.46       -99.99
# 643692    19.12       -99.99    18.21       -99.99
# 643693    15.88       -99.99    14.01       -99.99
# 643694    24.25       -99.99    22.71       -99.99
# 643695    24.29       -99.99    23.09       -99.99
# 643696    21.96       -99.99    21.29       -99.99
# 643697    21.73       -99.99    21.13       -99.99
# 643698    21.30       -99.99    21.30       -99.99
# 643699    21.93       -99.99    20.77       -99.99
# 645032    13.32       -99.99    12.25       -99.99
# 645033    11.99       -99.99    11.55       -99.99
# 645034    13.05       -99.99    12.28       -99.99
# 645039    14.75       -99.99    14.27       -99.99
# 645040    17.92       -99.99    16.88       -99.99
# 645041    17.76       -99.99    14.89       -99.99
# 645042    17.39       -99.99    16.40       -99.99
# 645043    17.35       -99.99    16.97       -99.99
# 645044    16.49       -99.99    15.68       -99.99
# 645045    19.02       -99.99    17.39       -99.99
# 645046    13.93       -99.99    14.69       -99.99
# 645047    20.86       -99.99    18.46       -99.99
# 645048    27.70       -99.99    26.77       -99.99
# 645049    22.67       -99.99    21.72       -99.99
# 645050    18.30       -99.99    18.37       -99.99
# 645051    22.08       -99.99    20.68       -99.99
# 645052    19.63       -99.99    20.47       -99.99
# 645053    22.99       -99.99    22.60       -99.99
# 645054    17.66       -99.99    19.71       -99.99
# 646387    11.24       -99.99    12.10       -99.99
# 646388    12.64       -99.99    12.24       -99.99
# 646392    16.70       -99.99    15.23       -99.99
# 646393    19.64       -99.99    17.04       -99.99
# 646394    15.23       -99.99    13.90       -99.99
# 646395    15.27       -99.99    12.86       -99.99
# 646396    17.09       -99.99    15.81       -99.99
# 646397    12.73       -99.99    13.22       -99.99
# 646398    14.02       -99.99    14.18       -99.99
# 646399    15.86       -99.99    15.27       -99.99
# 646400    16.85       -99.99    15.54       -99.99
# 646401    21.68       -99.99    20.69       -99.99
# 646402    21.11       -99.99    20.84       -99.99
# 646403    18.79       -99.99    19.68       -99.99
# 646404    18.00       -99.99    17.49       -99.99
# 646405    20.51       -99.99    20.02       -99.99
# 646406    19.46       -99.99    19.98       -99.99
# 646407    23.28       -99.99    22.42       -99.99
# 647746    17.90       -99.99    16.30       -99.99
# 647747    19.53       -99.99    17.06       -99.99
# 647748    15.38       -99.99    13.76       -99.99
# 647749    18.48       -99.99    16.75       -99.99
# 647750    15.42       -99.99    15.57       -99.99
# 647751    18.23       -99.99    16.16       -99.99
# 647752    19.20       -99.99    17.81       -99.99
# 647753    17.50       -99.99    16.70       -99.99
# 647754    19.17       -99.99    17.81       -99.99
# 647755    24.86       -99.99    21.58       -99.99
# 647756    21.98       -99.99    20.94       -99.99
# 647757    21.15       -99.99    19.84       -99.99
# 647758    22.76       -99.99    20.40       -99.99
# 647759    22.51       -99.99    20.38       -99.99
# 647760    27.24       -99.99    24.27       -99.99
# 647761    22.11       -99.99    22.47       -99.99
# 649104    18.20       -99.99    15.47       -99.99
# 649105    16.99       -99.99    15.40       -99.99
# 649106    15.46       -99.99    15.06       -99.99
# 649107    12.20       -99.99    12.32       -99.99
# 649108    19.20       -99.99    17.71       -99.99
# 649109    18.99       -99.99    18.21       -99.99
# 649110    18.45       -99.99    18.33       -99.99
# 649111    15.58       -99.99    17.04       -99.99
# 649112    21.52       -99.99    19.80       -99.99
# 649113    19.89       -99.99    19.68       -99.99
# 649114    15.80       -99.99    17.89       -99.99
# 649115    16.36       -99.99    18.52       -99.99
# 650462    24.78       -99.99    22.56       -99.99
# 650463    20.68       -99.99    19.90       -99.99
# 650464    22.01       -99.99    21.21       -99.99
# 650465    17.78       -99.99    17.71       -99.99
# 650466    20.49       -99.99    20.25       -99.99
# 650467    19.66       -99.99    20.08       -99.99
# 650468    23.55       -99.99    22.52       -99.99
# 650469    20.02       -99.99    20.22       -99.99
# 651821    23.70       -99.99    22.59       -99.99
# 651822    23.33       -99.99    21.49       -99.99
# 651823    18.16       -99.99    19.87       -99.99

# %%
df[0:2]
# Out:
#    Unnamed: 0  CER_UC_16  CER_UC_21  CER_UC_37  CMLF  COT_16  COT_16_PCL  \
# 0           0      -9999      -9999      -9999     0  -99.99      -99.99
# 1           1      -9999        537      -9999     1  -99.99      -99.99
#
#    COT_21  COT_21_PCL  COT_37  COT_37_PCL  CPI  CPOP   CTH  CTP     CTT  \
# 0  -99.99      -99.99  -99.99      -99.99    2     0  8850  315  227.77
# 1  -99.99        1.04  -99.99      -99.99    2     3  9450  285  222.64
#
#    CWP_16  CWP_16_PCL  CWP_21  CWP_21_PCL  CWP_37  CWP_37_PCL  \
# 0   -9999       -9999   -9999       -9999   -9999       -9999
# 1   -9999       -9999   -9999          24   -9999       -9999
#
#              FDate    SZA       lat1       long1  reff_16  reff_16_PCL  \
# 0  20130614_133658  80.56 -44.494007  162.621780   -99.99       -99.99
# 1  20130614_133658  80.55 -44.511356  162.564346   -99.99       -99.99
#
#    reff_21  reff_21_PCL  reff_37  reff_37_PCL
# 0   -99.99       -99.99   -99.99       -99.99
# 1   -99.99        38.10   -99.99       -99.99

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
